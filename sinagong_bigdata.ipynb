# %% [markdown]
# <a href="https://colab.research.google.com/github/va4756/yemoon_bigdata_test/blob/main/sinagong_bigdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 동기화

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/lovedlim/bigdata_analyst_cert_v2
# Out:
# Cloning into 'bigdata_analyst_cert_v2'...
# remote: Enumerating objects: 278, done.
# remote: Counting objects: 100% (278/278), done.
# remote: Compressing objects: 100% (267/267), done.
# remote: Total 278 (delta 71), reused 16 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (278/278), 6.77 MiB | 6.20 MiB/s, done.
# Resolving deltas: 100% (71/71), done.

# %% [markdown]
# ## 2회 기출문제

# %% [markdown]
# ### 제 1 유형 문제

# %% [markdown]
# #### 문제 1-1

# %%
import pandas as pd
df = pd.read_csv('/content/bigdata_analyst_cert_v2/part4/ch2/members.csv')
print(df.shape)
df.head()
# Out:
# (100, 10)
#      id   age city    f1  f2    f3    f4         f5  subscribed   views
# 0  id01   2.0   서울   NaN   0  gold  ENFJ  91.297791  2021-07-16  6820.0
# 1  id02   9.0   서울  70.0   1   NaN  ENFJ  60.339826  2021-05-12  2534.0
# 2  id03  27.0   서울  61.0   1  gold  ISTJ  17.252986  2021-03-16  7312.0
# 3  id04  75.0   서울   NaN   2   NaN  INFP  52.667078  2021-07-21   493.0
# 4  id05  24.0   서울  85.0   2   NaN  ISFJ  29.269869  2021-03-07  1338.0

# %%
# 1) views 컬럼 내림차순 정렬
df1 = df.copy()
df1.sort_values('views', ascending=False, inplace=True)
df1.head()

# 2) 상위 10개 중에서 10번째 (최소값) 값 구하기
min_val = df1['views'][:10].min()
min_val

# 3) 상위 10개 중에서 10번째 (최소값) 값 대체
df1.loc[:9, 'views'] = min_val
df1.head(11)

# 4) age가 80 이상의 views 컬럼 평균
cond = df1['age'] >= 80
result = df1[cond]['views'].mean()
result

# 5) 반올림하여 소수 둘째자리까지 계산
round(result, 2)
# Out:
# np.float64(5674.96)

# %% [markdown]
# #### 문제 1-2

# %%
import pandas as pd
df = pd.read_csv('/content/bigdata_analyst_cert_v2/part4/ch2/members.csv')
print(df.shape)
df.head()
# Out:
# (100, 10)
#      id   age city    f1  f2    f3    f4         f5  subscribed   views
# 0  id01   2.0   서울   NaN   0  gold  ENFJ  91.297791  2021-07-16  6820.0
# 1  id02   9.0   서울  70.0   1   NaN  ENFJ  60.339826  2021-05-12  2534.0
# 2  id03  27.0   서울  61.0   1  gold  ISTJ  17.252986  2021-03-16  7312.0
# 3  id04  75.0   서울   NaN   2   NaN  INFP  52.667078  2021-07-21   493.0
# 4  id05  24.0   서울  85.0   2   NaN  ISFJ  29.269869  2021-03-07  1338.0

# %%
df1 = df.copy()
# 1) 앞에서 부터 80% 데이터 슬라이싱
line = int(len(df1) * 0.8)
df1 = df1.iloc[:line]
df1.shape

# 2) 결측치 채우기 전 'f1' 컬럼 표준편차 구하기
df1['f1'].isnull().sum()
std1 = df1['f1'].std()
# std1

# 3) 중앙값으로 결측치 채우기
med = df1['f1'].median()
df1['f1'] = df1['f1'].fillna(med)
# df1.head()

# 4) 결측치를 채운 후 'f1' 컬럼 표준편차 구하기
std2 = df1['f1'].std()

# 5) 두 표준편차 차이 절대값 계산 (반올림하여 소수 둘째자리까지 계산)
result = abs(std1 - std2)
round(result, 2)
# Out:
# 3.56
