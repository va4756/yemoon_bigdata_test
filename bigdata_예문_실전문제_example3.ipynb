# %% [markdown]
# <a href="https://colab.research.google.com/github/va4756/yemoon_bigdata_test/blob/main/bigdata_%EC%98%88%EB%AC%B8_%EC%8B%A4%EC%A0%84%EB%AC%B8%EC%A0%9C_example3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6회 기출문제

# %% [markdown]
# ## 데이터 동기화

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/AnalyticsKnight/yemoonsaBigdata/
# Out:
# fatal: destination path 'yemoonsaBigdata' already exists and is not an empty directory.

# %% [markdown]
# ## 제 1유형 문제

# %% [markdown]
# ### 문1-1) 소방서별신고접수, 출발시간 도착시간 데이터셋이다.
# -  대응시간(신고접수 후 대응시간까지), 출동시간을 정의하고(출발시간에서 도착시간까지)
# - 소방서별 출동시간 평균이 가장 큰 소방서를 구하고
# - 출동시간 평균을 구한다.

# %%
# 데이터 불러오기
import pandas as pd
path = '/content/yemoonsaBigdata/datasets/Part5/ex6/'
file = path + '06.01.01-Fire Station Data.csv'

df = pd.read_csv(file, encoding='cp949')
df.head()
# Out:
#       소방서ID            신고접수시간              출발시간              도착시간
# 0  StationS  2023-07-08 21:05  2023-07-08 21:09  2023-07-08 21:37
# 1  StationI   2023-06-04 8:11   2023-06-04 8:14   2023-06-04 8:58
# 2  StationJ  2023-01-31 16:20  2023-01-31 16:23  2023-01-31 16:44
# 3  StationD  2023-03-10 17:31  2023-03-10 17:32  2023-03-10 18:03
# 4  StationB   2023-06-18 7:23   2023-06-18 7:26   2023-06-18 8:18

# %% [markdown]
# #### 1-02 신고접수시간, 출발시간, 도착시간 날짜타입 변환하기

# %%
df1 = df.copy()
df1['신고접수시간'] = pd.to_datetime(df1['신고접수시간'])
df1['출발시간'] = pd.to_datetime(df1['출발시간'])
df1['도착시간'] = pd.to_datetime(df1['도착시간'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 993 entries, 0 to 992
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   소방서ID   993 non-null    object
#  1   신고접수시간  993 non-null    datetime64[ns]
#  2   출발시간    993 non-null    datetime64[ns]
#  3   도착시간    993 non-null    datetime64[ns]
# dtypes: datetime64[ns](3), object(1)
# memory usage: 31.2+ KB

# %% [markdown]
# #### 1-03 대응시간, 출동시간 값 구하기

# %%
# 대응시간, 출동시간 값 구하기
df1['대응시간'] = df1['도착시간'] - df1['신고접수시간']
df1['출동시간'] = df1['도착시간'] - df1['출발시간']

#대응시간, 출동시간을 초로 변환하기
df1['대응시간'] = df1['대응시간'].dt.total_seconds()
df1['출동시간'] = df1['출동시간'].dt.total_seconds()

print(df1)
# Out:
#         소방서ID              신고접수시간                출발시간                도착시간  \
# 0    StationS 2023-07-08 21:05:00 2023-07-08 21:09:00 2023-07-08 21:37:00
# 1    StationI 2023-06-04 08:11:00 2023-06-04 08:14:00 2023-06-04 08:58:00
# 2    StationJ 2023-01-31 16:20:00 2023-01-31 16:23:00 2023-01-31 16:44:00
# 3    StationD 2023-03-10 17:31:00 2023-03-10 17:32:00 2023-03-10 18:03:00
# 4    StationB 2023-06-18 07:23:00 2023-06-18 07:26:00 2023-06-18 08:18:00
# ..        ...                 ...                 ...                 ...
# 988  StationP 2023-05-14 15:22:00 2023-05-14 15:23:00 2023-05-14 15:29:00
# 989  StationY 2023-06-07 21:59:00 2023-06-07 22:02:00 2023-06-07 22:21:00
# 990  StationO 2023-09-23 01:07:00 2023-09-23 01:12:00 2023-09-23 01:55:00
# 991  StationW 2023-07-24 11:21:00 2023-07-24 11:22:00 2023-07-24 12:02:00
# 992  StationE 2023-06-22 18:13:00 2023-06-22 18:14:00 2023-06-22 18:38:00
#
#        대응시간    출동시간
# 0    1920.0  1680.0
# 1    2820.0  2640.0
# ...

# %% [markdown]
# #### 1-04 출동시간 평균 구하기

# %%
# 소방소별 출동시간 평균 구하기
dg = df1.groupby('소방서ID')[['출동시간']].mean()
dg = dg.reset_index()
dg.head()
# Out:
#       소방서ID         출동시간
# 0  StationA  1482.000000
# 1  StationB  1921.463415
# 2  StationC  1806.521739
# 3  StationD  2003.636364
# 4  StationE  1712.000000

# %% [markdown]
# #### 1-05 출동시간 평균으로 출동시간이 가장 긴 소방서 찾기

# %%
# 소방소별 출동시간 평균으로 내림차순 정렬하기
dg = dg.sort_values(by='출동시간', ascending=False)
dg.head()
# Out:
#        소방서ID         출동시간
# 25  StationZ  2276.250000
# 13  StationN  2106.857143
# 12  StationM  2010.000000
# 3   StationD  2003.636364
# 22  StationW  1988.780488

# %%
#출동시간이 가장 긴 소방서 찾기
result = dg.iloc[0]['소방서ID']
print(result)
# Out:
# StationZ

# %% [markdown]
# ### 문1-2) 초등학교 학년별 학생와 교사수에 대한 데이터셋이다.
# - 교사1인당 학생수가 가장 많은 학교를 찾는다.
# - 그 학교의 전체 학생수를 구하시오.

# %%
import pandas as pd

file = path + '06.01.02-Elementary School Data.csv'
df = pd.read_csv(file, encoding='cp949') #, encoding='cp949'

df1 = df.copy()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   School Name  300 non-null    object
#  1   1G Students  300 non-null    int64
#  2   2G Students  300 non-null    int64
#  3   3G Students  300 non-null    int64
#  4   4G Students  300 non-null    int64
#  5   5G Students  300 non-null    int64
#  6   6G Students  300 non-null    int64
#  7   Teachers     300 non-null    int64
# dtypes: int64(7), object(1)
# memory usage: 18.9+ KB

# %% [markdown]
# #### 2-02 교사 1인당 학생수 구하기

# %%
#전체 학생수 구하기
df1['Students'] = df1[['1G Students', '2G Students', '3G Students', '4G Students', '5G Students', '6G Students']].sum(axis=1)
df1.head()
# Out:
#   School Name  1G Students  2G Students  3G Students  4G Students  \
# 0         ES1           64           48           84           78
# 1         ES2           58           62           82           73
# 2         ES3           64           79           99           49
# 3         ES4           60           96           48           69
# 4         ES5           56           71           69           32
#
#    5G Students  6G Students  Teachers  Students
# 0           24           38        15       336
# 1           42           63        15       380
# 2           80           73        23       444
# 3           47           26        18       346
# 4           33          100        22       361

# %%
#교사 1인당 학생수 구하기
df1['Std per Teachers'] = df1['Students'] / df1['Teachers']
df1.head()
# Out:
#   School Name  1G Students  2G Students  3G Students  4G Students  \
# 0         ES1           64           48           84           78
# 1         ES2           58           62           82           73
# 2         ES3           64           79           99           49
# 3         ES4           60           96           48           69
# 4         ES5           56           71           69           32
#
#    5G Students  6G Students  Teachers  Students  Std per Teachers
# 0           24           38        15       336         22.400000
# 1           42           63        15       380         25.333333
# 2           80           73        23       444         19.304348
# 3           47           26        18       346         19.222222
# 4           33          100        22       361         16.409091

# %% [markdown]
# #### 2-03 교사 1인당 학생수가 가장 많은 학교를 찾아 학생수 출력하기

# %%
#교사 1인당 학생수가 가장 많은 학교 찾기
#max  사용
result = df1[df1['Std per Teachers'] == df1['Std per Teachers'].max()][['School Name', 'Students']]
result
# Out:
#    School Name  Students
# 86        ES87       245

# %%
result = result['Students']
result
# Out:
# 86    245
# Name: Students, dtype: int64

# %% [markdown]
# ### 문1-3) 경찰서별 월별 발생한 범죄데이터
# - 2021년 대비 2022년의 연평균 범죄율을 구한다.
# - 가장 많이 늘어난 경찰서의 데이터를 구하고,
# - 이 경찰서의 2021년 교통범죄의 데이터를 구하시오.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/AnalyticsKnight/yemoonsaBigdata/
# Out:
# fatal: destination path 'yemoonsaBigdata' already exists and is not an empty directory.

# %%
import pandas as pd

# file = path + '06.01.03-Crime Data.csv'
df = pd.read_csv('/content/yemoonsaBigdata/datasets/Part5/ex6/06.01.03-Crime Data.csv')
print(df.head())
# Out:
#   Police Station  Year-Month  Violent  Theft  Traffic  Intelligence  \
# 0           PS 1  2021-01-31       36     42       42            20
# 1           PS 1  2021-02-28       25     21       32             1
# 2           PS 1  2021-03-31       45      7       36            46
# 3           PS 1  2021-04-30       43     24        2             2
# 4           PS 1  2021-05-31       23     36       11             2
#
#    Against Morals  Special Economic  Drug  Health  Environmental  Labor  \
# 0              12                27    35      26              7     16
# 1              20                22     0      49             47      7
# 2              35                46     9      34             17     33
# 3              18                41    37       1              0     44
# 4              36                44    29      34             47     25
#
#    Security  Election  Military  Other
# 0         6        18        13     17
# 1         2        15         2     47
# ...

# %%
print(df.shape)
df.info()
# Out:
# (480, 16)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Police Station    480 non-null    object
#  1   Year-Month        480 non-null    object
#  2   Violent           480 non-null    int64
#  3   Theft             480 non-null    int64
#  4   Traffic           480 non-null    int64
#  5   Intelligence      480 non-null    int64
#  6   Against Morals    480 non-null    int64
#  7   Special Economic  480 non-null    int64
#  8   Drug              480 non-null    int64
#  9   Health            480 non-null    int64
#  10  Environmental     480 non-null    int64
#  11  Labor             480 non-null    int64
#  12  Security          480 non-null    int64
#  13  Election          480 non-null    int64
#  14  Military          480 non-null    int64
#  15  Other             480 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['Police Station', 'Year-Month', 'Violent', 'Theft', 'Traffic',
#        'Intelligence', 'Against Morals', 'Special Economic', 'Drug', 'Health',
#        'Environmental', 'Labor', 'Security', 'Election', 'Military', 'Other'],
#       dtype='object')

# %%
df1 = df.copy()

# %%
# 날짜 데이터로 바꾸기
df1['Year-Month']= pd.to_datetime(df1['Year-Month'])

# %%
df1['Year']= df1['Year-Month'].dt.year

# %%
df1.head()
# Out:
#   Police Station Year-Month  Violent  Theft  Traffic  Intelligence  \
# 0           PS 1 2021-01-31       36     42       42            20
# 1           PS 1 2021-02-28       25     21       32             1
# 2           PS 1 2021-03-31       45      7       36            46
# 3           PS 1 2021-04-30       43     24        2             2
# 4           PS 1 2021-05-31       23     36       11             2
#
#    Against Morals  Special Economic  Drug  Health  Environmental  Labor  \
# 0              12                27    35      26              7     16
# 1              20                22     0      49             47      7
# 2              35                46     9      34             17     33
# 3              18                41    37       1              0     44
# 4              36                44    29      34             47     25
#
#    Security  Election  Military  Other  Year
# 0         6        18        13     17  2021
# ...

# %%
#경찰서별, 월별 토탈 범죄 데이터 생성하기
df1.loc[:, 'Total'] = df.loc[:, 'Violent':'Other'].sum(axis=1)
df1
# Out:
#     Police Station Year-Month  Violent  Theft  Traffic  Intelligence  \
# 0             PS 1 2021-01-31       36     42       42            20
# 1             PS 1 2021-02-28       25     21       32             1
# 2             PS 1 2021-03-31       45      7       36            46
# 3             PS 1 2021-04-30       43     24        2             2
# 4             PS 1 2021-05-31       23     36       11             2
# ..             ...        ...      ...    ...      ...           ...
# 475          PS 20 2022-08-31       50      8       16             4
# 476          PS 20 2022-09-30       10     10        5             7
# 477          PS 20 2022-10-31       25     29        1            31
# 478          PS 20 2022-11-30       17     25        4            10
# 479          PS 20 2022-12-31       27     40       18            23
#
#      Against Morals  Special Economic  Drug  Health  Environmental  Labor  \
# ...

# %%
#경찰서 별,년도별 트래픽, 토탈 범죄 데이터 합산
df2 = df1[['Police Station', 'Year', 'Traffic', 'Total']].groupby(by=['Police Station', 'Year']).sum(['Traffic', 'Total']).reset_index()
df2.head()
# Out:
#   Police Station  Year  Traffic  Total
# 0           PS 1  2021      319   4340
# 1           PS 1  2022      271   3927
# 2          PS 10  2021      297   4421
# 3          PS 10  2022      252   3873
# 4          PS 11  2021      353   4187

# %%
# 21년 대비 22년 범죄가 가장 많이 늘어난 경찰서 찾기
df21 = df2[df2['Year'] == 2021][['Police Station', 'Year', 'Total']]
df22 = df2[df2['Year'] == 2022][['Police Station', 'Year', 'Total']]
df3 = pd.merge(df21, df22, on='Police Station')
df3.head()
# Out:
#   Police Station  Year_x  Total_x  Year_y  Total_y
# 0           PS 1    2021     4340    2022     3927
# 1          PS 10    2021     4421    2022     3873
# 2          PS 11    2021     4187    2022     3956
# 3          PS 12    2021     4027    2022     4159
# 4          PS 13    2021     4024    2022     4242

# %%
df3['Increase'] = df3['Total_y'] - df3['Total_x']
most_incr_st = df3.loc[df3['Increase'] == df3['Increase'].max()]['Police Station'].item()
most_incr_st
# Out:
# 'PS 2'

# %%
result = df2[(df2['Police Station'] == most_incr_st) & (df2['Year'] == 2021)]['Traffic'].item()
result
# Out:
# 306

# %% [markdown]
# ## 제 2유형 문제

# %% [markdown]
# ### (문제) E-Commerce Shipping 데이터셋이다. 주어진 훈련데이터셋을 이용하여 고객이 주문한 물품의 정시 도착 여부를 예측하고 예측 결과를 CSV 파일로 제출하시오.
# - 예측값의 ROC-AUC 점수 결과로 점수를 매김

# %%
import pandas as pd
X_test = pd.read_csv("yemoonsaBigdata/datasets/Part5/204_x_test.csv")
X_train = pd.read_csv("yemoonsaBigdata/datasets/Part5/204_x_train.csv")
y_train = pd.read_csv("yemoonsaBigdata/datasets/Part5/204_y_train.csv")

# %% [markdown]
# #### 1.데이터 분석 작업

# %%
print(X_train.shape, X_test.shape, y_train.shape)
# Out:
# (6599, 11) (4400, 11) (6599, 2)

# %%
X_train.head()
# Out:
#       ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0   9902               F             Ship                    3
# 1   9501               A             Ship                    4
# 2   6111               A             Ship                    4
# 3    588               F             Ship                    3
# 4  10806               F             Road                    5
#
#    Customer_rating  Cost_of_the_Product  Prior_purchases Product_importance  \
# 0                5                  214                2             medium
# 1                2                  201                3             medium
# 2                2                  264                3                low
# 3                5                  194                2             medium
# 4                5                  269                5             medium
#
#   Gender  Discount_offered  Weight_in_gms
# 0      F                 6           4578
# 1      F                 4           4613
# ...

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6599 entries, 0 to 6598
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   6599 non-null   int64
#  1   Warehouse_block      6599 non-null   object
#  2   Mode_of_Shipment     6599 non-null   object
#  3   Customer_care_calls  6599 non-null   int64
#  4   Customer_rating      6599 non-null   int64
#  5   Cost_of_the_Product  6599 non-null   int64
#  6   Prior_purchases      6599 non-null   int64
#  7   Product_importance   6599 non-null   object
#  8   Gender               6599 non-null   object
#  9   Discount_offered     6599 non-null   int64
#  10  Weight_in_gms        6599 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 567.2+ KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6599 entries, 0 to 6598
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   6599 non-null   int64
#  1   Reached.on.Time_Y.N  6599 non-null   int64
# dtypes: int64(2)
# memory usage: 103.2 KB

# %%
X_train.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# dtype: int64

# %%
y_train.isnull().sum()
# Out:
# ID                     0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
X_train.columns
# Out:
# Index(['ID', 'Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls',
#        'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases',
#        'Product_importance', 'Gender', 'Discount_offered', 'Weight_in_gms'],
#       dtype='object')

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6599 entries, 0 to 6598
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   6599 non-null   int64
#  1   Warehouse_block      6599 non-null   object
#  2   Mode_of_Shipment     6599 non-null   object
#  3   Customer_care_calls  6599 non-null   int64
#  4   Customer_rating      6599 non-null   int64
#  5   Cost_of_the_Product  6599 non-null   int64
#  6   Prior_purchases      6599 non-null   int64
#  7   Product_importance   6599 non-null   object
#  8   Gender               6599 non-null   object
#  9   Discount_offered     6599 non-null   int64
#  10  Weight_in_gms        6599 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 567.2+ KB

# %% [markdown]
# #### 2.각각의 열에 대해 분리작업

# %%
COL_DEL = ["ID"]
COL_NUM = ['Customer_care_calls', 'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases', 'Discount_offered', 'Weight_in_gms']
COL_CAT = ['Warehouse_block', 'Mode_of_Shipment', 'Product_importance', 'Gender']
COL_Y = ['Reached.on.Time_Y.N']

# %% [markdown]
# #### 3.데이터 모형 구축

# %%
from sklearn.model_selection import train_test_split
X_tr, X_val, y_tr, y_val = train_test_split(X_train[COL_NUM+COL_CAT],
                                                  y_train[COL_Y],
                                                  test_size=0.3,
                                                  stratify=y_train[COL_Y])
X_tr.shape, X_val.shape, y_tr.shape, y_val.shape
# Out:
# ((4619, 10), (1980, 10), (4619, 1), (1980, 1))

# %%
y_train
# Out:
#          ID  Reached.on.Time_Y.N
# 0      9902                    0
# 1      9501                    0
# 2      6111                    1
# 3       588                    1
# 4     10806                    0
# ...     ...                  ...
# 6594   3086                    1
# 6595   7154                    0
# 6596   4897                    0
# 6597  10553                    0
# 6598   4081                    0
#
# [6599 rows x 2 columns]

# %% [markdown]
# #### 4.스케일링 작업 시행

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_tr[COL_NUM])

X_tr[COL_NUM] = scaler.transform(X_tr[COL_NUM])
X_val[COL_NUM] = scaler.transform(X_val[COL_NUM])
X_test[COL_NUM] = scaler.transform(X_test[COL_NUM])

# %%
X_tr[COL_NUM].head()
# Out:
#       Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# 888             -0.040807         0.718109             0.185500
# 4448            -0.040807        -0.699086             0.681298
# 3613             0.839971         1.426707             1.053147
# 3409             0.839971        -1.407684             1.073805
# 619              1.720749        -0.699086             1.652237
#
#       Prior_purchases  Discount_offered  Weight_in_gms
# 888          0.315681          2.021980      -0.249925
# 4448         1.662062         -0.187856       1.232898
# 3613        -1.030700          0.632940      -0.353434
# 3409        -0.357510          0.759216      -0.090679
# 619          0.988872         -0.187856      -1.246435

# %% [markdown]
# #### 5.인코딩 작업 실시
# - 범주형 변수에 대해

# %%
from sklearn.preprocessing import LabelEncoder

X = pd.concat([X_train[COL_CAT], X_test[COL_CAT]])

for col in COL_CAT:
    le = LabelEncoder()
    le.fit(X[col])
    X_tr[col] = le.transform(X_tr[col])
    X_val[col] = le.transform(X_val[col])
    X_test[col] = le.transform(X_test[col])

    print(col)
    print(le.classes_)
    print('\n')
# Out:
# Warehouse_block
# ['A' 'B' 'C' 'D' 'F']
#
#
# Mode_of_Shipment
# ['Flight' 'Road' 'Ship']
#
#
# Product_importance
# ['high' 'low' 'medium']
#
#
# Gender
# ['F' 'M']

# %%
X_tr[COL_CAT].head()
# Out:
#       Warehouse_block  Mode_of_Shipment  Product_importance  Gender
# 888                 4                 2                   1       1
# 4448                1                 2                   2       0
# 3613                4                 2                   1       0
# 3409                2                 2                   1       1
# 619                 1                 2                   2       0

# %% [markdown]
# #### 6.모형학습

# %%
# 1) 랜덤포레스트
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier(random_state=123)
model_rf.fit(X_tr, y_tr)

# 2) XGBoost
from xgboost import XGBClassifier

model_xgb = XGBClassifier()
model_xgb.fit(X_tr, y_tr)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %% [markdown]
# #### 7. 데이터 모형 평가

# %% [markdown]
# ##### 7.1 검증 데이터로 예측값 생성

# %%
X_val.head()
# Out:
#       Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# 2586            -0.921585        -1.407684            -1.818353
# 201             -0.040807         0.009511             0.825906
# 1896            -0.040807         0.009511            -1.363871
# 3867             0.839971        -1.407684             0.516032
# 4673             2.601527         0.009511             1.796845
#
#       Prior_purchases  Discount_offered  Weight_in_gms  Warehouse_block  \
# 2586         0.988872          3.095329      -1.308909                4
# 201          0.315681         -0.187856       1.207786                2
# 1896        -1.030700         -0.756100       0.465456                4
# 3867         0.988872         -0.314133      -1.105564                4
# 4673         0.315681         -0.692962      -1.432018                0
#
#       Mode_of_Shipment  Product_importance  Gender
# 2586                 2                   1       1
# ...

# %%
y_pred_rf = model_rf.predict(X_val)
y_pred_xgb = model_xgb.predict(X_val)

# %% [markdown]
# ##### 7.2 평가지표 구하기

# %%
## 답안 채점 기준인 roc_auc 사용
from sklearn.metrics import roc_auc_score

score_rf = roc_auc_score(y_val, y_pred_rf)
score_xgb = roc_auc_score(y_val, y_pred_xgb)

print('Random Forest: ', score_rf)
print('XGBoost: ', score_xgb)
# Out:
# Random Forest:  0.6562631197282546
# XGBoost:  0.6449562993778863

# %% [markdown]
# ##### 7.3 학습, 검증 성능 확인 함수

# %%
def get_scores(model, X_tr, X_val, y_tr, y_val):

  y_tr_pred = model.predict_proba(X_tr)[:, 1]
  y_val_pred = model.predict_proba(X_val)[:, 1]
  tr_score = roc_auc_score(y_tr, y_tr_pred)
  val_score = roc_auc_score(y_val, y_val_pred)

  return f'train: {round(tr_score, 4)}, valid: {round(val_score, 4)}'

# %%
print('Random Forest \t-', get_scores(model_rf, X_tr, X_val, y_tr, y_val))
print('XGBoost \t-', get_scores(model_xgb, X_tr, X_val, y_tr, y_val))
# Out:
# Random Forest 	- train: 1.0, valid: 0.7324
# XGBoost 	- train: 0.9914, valid: 0.7378

# %% [markdown]
# ##### 7.4 하이퍼 파라미터 튜닝

# %%
modelXGB2 = XGBClassifier(n_estimators=30, max_depth=3, min_child_weight=1, random_state=123)
modelXGB2.fit(X_tr, y_tr)

modelXGB3 = XGBClassifier(n_estimators=30, max_depth=5, min_child_weight=1, random_state=123)
modelXGB3.fit(X_tr, y_tr)

modelXGB4 = XGBClassifier(n_estimators=50, max_depth=3, min_child_weight=1, random_state=123)
modelXGB4.fit(X_tr, y_tr)

modelXGB5 = XGBClassifier(n_estimators=50, max_depth=5, min_child_weight=1, random_state=123)
modelXGB5.fit(X_tr, y_tr)

print('XGBoost2 \t-', get_scores(modelXGB2, X_tr, X_val, y_tr, y_val))
print('XGBoost3 \t-', get_scores(modelXGB3, X_tr, X_val, y_tr, y_val))
print('XGBoost4 \t-', get_scores(modelXGB4, X_tr, X_val, y_tr, y_val))
print('XGBoost5 \t-', get_scores(modelXGB5, X_tr, X_val, y_tr, y_val))
# Out:
# XGBoost2 	- train: 0.8111, valid: 0.7338
# XGBoost3 	- train: 0.8796, valid: 0.7261
# XGBoost4 	- train: 0.8386, valid: 0.7328
# XGBoost5 	- train: 0.9218, valid: 0.733

# %% [markdown]
# ##### 7.5 최종 결과값 생성

# %%
pred = modelXGB5.predict_proba(X_test[COL_NUM+COL_CAT])[:, 1]
result = pd.DataFrame({'ID': X_test['ID'], 'pred': pred})
print(result.head())
# Out:
#       ID      pred
# 0   7007  0.424568
# 1   9793  0.464837
# 2   6593  0.615225
# 3  10527  0.298094
# 4   6914  0.548810

# %%
## 최종 결과 확인 후 to_csv 함수로 제출
# result.to_csv('003000000.csv', index=False)

# %% [markdown]
# ## 제 3유형 문제

# %% [markdown]
# ### 3-1) A 도시의 교통수단으로 버스,지하철, 택시, 자전거가 있다.
# - 교통수단의 실제 선택 비율은 40%, 30%, 20%, 10% 라고 예측함
# - 선호하는 교통수단에 대해 설문조사를 행함.
# - 이를 위해 수립한 귀무가설과 대립가설이 있을 때 다음의 검정을 행하시오.

# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/AnalyticsKnight/yemoonsaBigdata/
# Out:
# Mounted at /content/drive
# Cloning into 'yemoonsaBigdata'...
# remote: Enumerating objects: 743, done.
# remote: Counting objects: 100% (144/144), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 743 (delta 85), reused 63 (delta 63), pack-reused 599 (from 1)
# Receiving objects: 100% (743/743), 11.86 MiB | 13.63 MiB/s, done.
# Resolving deltas: 100% (360/360), done.

# %%
import pandas as pd
import scipy.stats as stats

df = pd.read_csv('/content/yemoonsaBigdata/datasets/Part5/ex6/06.03.01-transport_data.csv')
print(df.shape)
df.head()
# Out:
# (1000, 2)
#   User ID TransportMode
# 0      U1        subway
# 1      U2          taxi
# 2      U3        subway
# 3      U4        subway
# 4      U5        subway

# %% [markdown]
# #### (1-1) 설문조사 데이터에서 전체 건수에 대한 지하철을 선호하는 이용자의 비율을 구한다.

# %%
observe_data = df['TransportMode'].value_counts().sort_index()
observe_data
# Out:
# TransportMode
# bicycle    108
# bus        415
# subway     294
# taxi       183
# Name: count, dtype: int64

# %%
#지하철 선호 이용자 비율 구하기
total_counts = sum(observe_data)
subway_ratio = observe_data['subway'] / total_counts
subway_ratio = round(subway_ratio, 2)
subway_ratio
# Out:
# np.float64(0.29)

# %% [markdown]
# #### (1-2) 수가 동일한 비율을 보이는지 적합도를 검정하고 검정 통계량을 소수 둘째 짜리로 반올림 하시오.

# %%
expected_data = pd.Series({
    'bus': total_counts * 0.4,
    'subway': total_counts * 0.3,
    'taxi': total_counts * 0.2,
    'bicycle': total_counts * 0.1,
})
# 버스,지하철, 택시, 자전거: 40%, 30%, 20%, 10%

# %%
expected_data = expected_data.sort_index(ascending=True)
expected_data
# Out:
# bicycle    100.0
# bus        400.0
# subway     300.0
# taxi       200.0
# dtype: float64

# %%
expected_counts = expected_data.values
expected_counts
# Out:
# array([100., 400., 300., 200.])

# %%
#관찰(실제) 빈도 만들기
observed_counts = observe_data.values
observed_counts
# Out:
# array([108, 415, 294, 183])

# %%
#검정 통계량, pval 구하기
stat, pval = stats.chisquare(list(observed_counts), list(expected_counts))
stat = round(stat, 2)
stat
# Out:
# np.float64(2.77)

# %% [markdown]
# #### (1-3) 가설검정 결과 채택, 기각하기

# %%
print(pval)
result = '기각'
if pval >= 0.05:
    result = '채택'
print(result)
# Out:
# 0.42887797699846164
# 채택

# %% [markdown]
# ### 3-1) 물고기 무게를 다중회귀 분석으로 분석하는 문제
# - Y: Weight
# - X: 나머지 것들

# %%
import pandas as pd
import statsmodels.api as sm

# %%
df = pd.read_csv('/content/yemoonsaBigdata/datasets/Part5/ex6/06.03.02-fish_weight_data.csv')
print(df.shape)
df.head()
# Out:
# (100, 6)
#    id  Length  Height  Width  FinSize  Weight
# 0   1   63.91   28.72   3.46    18.22  194.32
# 1   2   77.22   14.45   7.12    15.71  194.59
# 2   3   68.22   30.73   4.09     7.33  191.24
# 3   4   63.59   38.68   2.21     2.54  194.23
# 4   5   53.89   13.71   0.73     8.74  131.82

# %% [markdown]
# #### (2-1) 다중회귀분석 모델 만들기
# - Length의 회귀계수는?

# %% [markdown]
# # 3회 기출문제

# %% [markdown]
# ## 제 1유형 문제

# %% [markdown]
# ### 문 1-1) California Housing 데이터셋에서 결측치가 있는 해당 데이터의 행을 제거하고/ 첫 번째 행부터 70%까지의 데이터를 추출해서/ 'housing_median_age'의 Q1 값을 정수로 출력

# %%
import pandas as pd

df = pd.read_csv("/content/yemoonsaBigdata/datasets/Part5/301_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
print(df.shape)
df.info()
# Out:
# (20640, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# #### 1.1.1 결측값 탐색하기

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# #### 1.1.2 결측값 제거하기

# %%
df_dropna = df.dropna().reset_index()
print('원본 데이터 갯수: ', len(df))
print('결측값 제거후 데이터 갯수: ', len(df_dropna))
# Out:
# 원본 데이터 갯수:  20640
# 결측값 제거후 데이터 갯수:  20433

# %% [markdown]
# #### 1.1.3 데이터 추출하기(70%)

# %%
rst_df = df_dropna.iloc[:int(len(df_dropna)*0.7)]
print('70% 추출한 데이터 건수: ', len(rst_df))
# Out:
# 70% 추출한 데이터 건수:  14303

# %% [markdown]
# #### 1.1.4 결과 출력하기

# %%
result = int(rst_df['housing_median_age'].quantile(0.25))
result
# Out:
# 19

# %% [markdown]
# ### 문1-2) 국가별 결핵 유병률 데이터셋에서/ 200년도의 평균값/ 보다 큰 유병률을 가진 국가의 수를 구하시오.

# %%
import pandas as pd

df = pd.read_csv("/content/yemoonsaBigdata/datasets/Part5/302_worlddata.csv")
df.head(5)
# Out:
#    year  Afghanistan  Albania  Algeria  Andorra  Angola  Antigua & Barbuda  \
# 0  1999            0     89.0     25.0    245.0   217.0              102.0
# 1  2000            0    132.0      0.0    138.0    57.0              128.0
# 2  2001            0     54.0     14.0    312.0    45.0               45.0
# 3  2002            0      4.9      0.7     12.4     5.9                4.9
#
#    Argentina  Armenia  Australia  ...  Tanzania    USA  Uruguay  Uzbekistan  \
# 0      193.0     21.0      261.0  ...      36.0  249.0    115.0        25.0
# 1       25.0    179.0       72.0  ...       6.0  158.0     35.0       101.0
# 2      221.0     11.0      212.0  ...       1.0   84.0    220.0         8.0
# 3        8.3      3.8       10.4  ...       5.7    8.7      6.6         2.4
#
#    Vanuatu  Venezuela  Vietnam  Yemen  Zambia  Zimbabwe
# 0     21.0      333.0      111    6.0    32.0      64.0
# 1     18.0      100.0        2    0.0    19.0      18.0
# ...

# %% [markdown]
# #### 1.2.1 데이터 추출하기

# %%
df_2000 = df[df['year'] == 2000].drop('year', axis=1)
df_2000.T
# Out:
#                  1
# Afghanistan    0.0
# Albania      132.0
# Algeria        0.0
# Andorra      138.0
# Angola        57.0
# ...            ...
# Venezuela    100.0
# Vietnam        2.0
# Yemen          0.0
# Zambia        19.0
# Zimbabwe      18.0
#
# [193 rows x 1 columns]

# %% [markdown]
# #### 1.2.2 행/열 변환

# %%
df_2000.index = ['value']
df_2000_T = df_2000.T
df_2000_T
# Out:
#              value
# Afghanistan    0.0
# Albania      132.0
# Algeria        0.0
# Andorra      138.0
# Angola        57.0
# ...            ...
# Venezuela    100.0
# Vietnam        2.0
# Yemen          0.0
# Zambia        19.0
# Zimbabwe      18.0
#
# [193 rows x 1 columns]

# %% [markdown]
# #### 1.2.3 데이터 추출하기

# %%
rst_df = df_2000_T[df_2000_T['value'] > df_2000_T['value'].mean()]
rst_df
# Out:
#                       value
# Albania               132.0
# Andorra               138.0
# Antigua & Barbuda     128.0
# Armenia               179.0
# Bahamas               176.0
# ...                     ...
# United Arab Emirates  135.0
# United Kingdom        126.0
# USA                   158.0
# Uzbekistan            101.0
# Venezuela             100.0
#
# [76 rows x 1 columns]

# %% [markdown]
# #### 1.2.4 결과 출력하기

# %%
result = len(rst_df)
result
# Out:
# 76

# %%
### 문1-3) Titanic 데이터셋에서의 컬럼 중 빈 또는 결측치를 확인하여/ 결측치의 비율이 가장 높은 변수명을 출력하기

# %%
import pandas as pd

df = pd.read_csv("/content/yemoonsaBigdata/datasets/Part5/303_titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   C85        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  C123        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        773 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          118
# Embarked         2
# dtype: int64

# %% [markdown]
# #### 1.3.1 결측값 개수 세기

# %%
rst_df = df.isnull().sum().reset_index()
rst_df.columns = ['var', 'count']
rst_df
# Out:
#             var  count
# 0   PassengerId      0
# 1      Survived      0
# 2        Pclass      0
# 3          Name      0
# 4           Sex      0
# 5           Age    177
# 6         SibSp      0
# 7         Parch      0
# 8        Ticket      0
# 9          Fare      0
# 10        Cabin    118
# 11     Embarked      2

# %% [markdown]
# #### 1.3.2 결과 출력하기

# %%
result = rst_df.loc[rst_df['count'] == rst_df['count'].max(), 'var'].values[0]
result
# Out:
# 'Age'

# %% [markdown]
# ## 제 2유형 문제

# %% [markdown]
# ### 문) Travel Insurance 데이터셋에서/ 훈련 데이터셋을 사용해서/ 고객별 여행보험 가입여부를 예측하는 모델을 만든다./ 가장 높은 Accuracy 값을 가지는 최종 모델을 도출하시오./ 이 모델을 활용하여 보험가입여부 예측값을 계산하고/ 결과값을 csv 파일로 제출하시오.

# %% [markdown]
# #### (1) 데이터 불러오기

# %%
# 데이터 파일 읽기 예제
import pandas as pd
X_train = pd.read_csv("yemoonsaBigdata/datasets/Part5/304_x_train.csv")
X_test = pd.read_csv("yemoonsaBigdata/datasets/Part5/304_x_test.csv")
y_train = pd.read_csv("yemoonsaBigdata/datasets/Part5/304_y_train.csv")

# pd.DataFrame({'index': X_test.index, 'y_pred': pred}).to_csv('003000000.csv', index=False)

# %%
print(X_train.shape, X_test.shape, y_train.shape)
X_train.head()
# Out:
# (1490, 9) (497, 9) (1490, 2)
#      ID  Age               Employment Type GraduateOrNot  AnnualIncome  \
# 0  1704   26  Private Sector/Self Employed           Yes       1400000
# 1   491   28  Private Sector/Self Employed           Yes       1100000
# 2   414   33  Private Sector/Self Employed           Yes       1400000
# 3   120   28  Private Sector/Self Employed           Yes        800000
# 4  1268   33             Government Sector           Yes       1000000
#
#    FamilyMembers  ChronicDiseases FrequentFlyer EverTravelledAbroad
# 0              3                1            No                 Yes
# 1              4                1            No                  No
# 2              4                0            No                 Yes
# 3              3                1            No                  No
# 4              5                0            No                 Yes

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1490 entries, 0 to 1489
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   1490 non-null   int64
#  1   Age                  1490 non-null   int64
#  2   Employment Type      1490 non-null   object
#  3   GraduateOrNot        1490 non-null   object
#  4   AnnualIncome         1490 non-null   int64
#  5   FamilyMembers        1490 non-null   int64
#  6   ChronicDiseases      1490 non-null   int64
#  7   FrequentFlyer        1490 non-null   object
#  8   EverTravelledAbroad  1490 non-null   object
# dtypes: int64(5), object(4)
# memory usage: 104.9+ KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1490 entries, 0 to 1489
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               1490 non-null   int64
#  1   TravelInsurance  1490 non-null   int64
# dtypes: int64(2)
# memory usage: 23.4 KB

# %% [markdown]
# #### (2) 데이터 전처리

# %% [markdown]
# ##### 2.1 변수별 결측치 수 확인

# %%
X_train.isnull().sum()
# Out:
# ID                     0
# Age                    0
# Employment Type        0
# GraduateOrNot          0
# AnnualIncome           0
# FamilyMembers          0
# ChronicDiseases        0
# FrequentFlyer          0
# EverTravelledAbroad    0
# dtype: int64

# %%
X_test.isnull().sum()
# Out:
# ID                     0
# Age                    0
# Employment Type        0
# GraduateOrNot          0
# AnnualIncome           0
# FamilyMembers          0
# ChronicDiseases        0
# FrequentFlyer          0
# EverTravelledAbroad    0
# dtype: int64

# %%
y_train.isnull().sum()
# Out:
# ID                 0
# TravelInsurance    0
# dtype: int64

# %% [markdown]
# ##### 2.2 변수 구분

# %%
X_train.columns
# Out:
# Index(['ID', 'Age', 'Employment Type', 'GraduateOrNot', 'AnnualIncome',
#        'FamilyMembers', 'ChronicDiseases', 'FrequentFlyer',
#        'EverTravelledAbroad'],
#       dtype='object')

# %%
COL_DEL = ['ID']
COL_NUM = ['Age', 'AnnualIncome', 'FamilyMembers', 'ChronicDiseases']
COL_CAT = ['Employment Type', 'GraduateOrNot', 'FrequentFlyer', 'EverTravelledAbroad']
COL_Y = ['TravelInsurance']

# %% [markdown]
# #### (3) 데이터 모형 구축

# %% [markdown]
# ##### 3.1 데이터 분할

# %%
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(X_train[COL_NUM + COL_CAT],
                                            y_train[COL_Y],
                                            test_size=0.3,
                                            stratify=y_train[COL_Y])

# %%
X_tr.head()
# Out:
#       Age  AnnualIncome  FamilyMembers  ChronicDiseases  \
# 673    29       1200000              4                0
# 1128   26       1450000              3                0
# 874    29        500000              7                0
# 1353   25       1400000              3                0
# 1098   33       1750000              6                0
#
#                    Employment Type GraduateOrNot FrequentFlyer  \
# 673   Private Sector/Self Employed           Yes           Yes
# 1128             Government Sector           Yes           Yes
# 874   Private Sector/Self Employed           Yes            No
# 1353  Private Sector/Self Employed           Yes            No
# 1098  Private Sector/Self Employed           Yes            No
#
#      EverTravelledAbroad
# 673                   No
# 1128                 Yes
# 874                   No
# 1353                 Yes
# 1098                  No

# %%
print(y_tr.value_counts())
# Out:
# TravelInsurance
# 0                  665
# 1                  378
# Name: count, dtype: int64

# %% [markdown]
# ##### 3.2 수치형 변수 - 데이터 스케일링

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_tr[COL_NUM])

X_tr[COL_NUM] = scaler.transform(X_tr[COL_NUM])
X_val[COL_NUM] = scaler.transform(X_val[COL_NUM])
X_test[COL_NUM] = scaler.transform(X_test[COL_NUM])

# %%
X_tr[COL_NUM].head()
# Out:
#            Age  AnnualIncome  FamilyMembers  ChronicDiseases
# 673  -0.209434      0.679807      -0.467759        -0.626517
# 1128 -1.233368      1.341470      -1.091638        -0.626517
# 874  -0.209434     -1.172850       1.403876        -0.626517
# 1353 -1.574680      1.209137      -1.091638        -0.626517
# 1098  1.155812      2.135466       0.779998        -0.626517

# %% [markdown]
# ##### 3.3 범주형 변수 - 데이터 인코딩

# %%
from sklearn.preprocessing import LabelEncoder

X = pd.concat([X_train[COL_CAT], X_test[COL_CAT]])

for col in COL_CAT:
    le = LabelEncoder()
    le.fit(X[col])
    X_tr[col] = le.transform(X_tr[col])
    X_val[col] = le.transform(X_val[col])
    X_test[col] = le.transform(X_test[col])

    # 각 변수의 클래스 확인
    print(col)
    print(le.classes_)
    print('\n')
# Out:
# Employment Type
# ['Government Sector' 'Private Sector/Self Employed']
#
#
# GraduateOrNot
# ['No' 'Yes']
#
#
# FrequentFlyer
# ['No' 'Yes']
#
#
# EverTravelledAbroad
# ['No' 'Yes']

# %%
X_tr[COL_CAT].head()
# Out:
#       Employment Type  GraduateOrNot  FrequentFlyer  EverTravelledAbroad
# 673                 1              1              1                    0
# 1128                0              1              1                    1
# 874                 1              1              0                    0
# 1353                1              1              0                    1
# 1098                1              1              0                    0

# %% [markdown]
# ##### 3.4 모형 학습

# %%
## 1) 랜덤 포레스트
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier(random_state=123)
model_rf.fit(X_tr, y_tr)

## 2) XGBoost
from xgboost import XGBClassifier

model_xgb = XGBClassifier()
model_xgb.fit(X_tr, y_tr)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %% [markdown]
# #### (4) 데이터 모형 평가

# %% [markdown]
# ##### 4.1 검증 데이터로 예측값 생성

# %%
y_pred_rf = model_rf.predict_proba(X_val)[:, 1]
y_pred_xgb = model_xgb.predict_proba(X_val)[:, 1]

# %% [markdown]
# ##### 4.2 평가지표 구하기

# %%
## 답안 채점 기준인 roc_auc 사용
from sklearn.metrics import roc_auc_score

score_rf = roc_auc_score(y_val, y_pred_rf)
score_xgb = roc_auc_score(y_val, y_pred_xgb)

print('Random Forest: \t', score_rf)
print('XGBoost: \t', score_xgb)
# Out:
# Random Forest: 	 0.7979965345462422
# XGBoost: 	 0.8036820446177171

# %% [markdown]
# ##### 4.3 학습, 검증 성능 확인 함수

# %%
def get_scores(model, X_tr, X_val, y_tr, y_val):

    y_tr_pred = model.predict_proba(X_tr)[:, 1]
    y_val_pred = model.predict_proba(X_val)[:, 1]
    tr_score = roc_auc_score(y_tr, y_tr_pred)
    val_score = roc_auc_score(y_val, y_val_pred)

    return f'train: {round(tr_score, 4)}, valid: {round(val_score, 4)}'

# %%
print('Random Forest \t-', get_scores(model_rf, X_tr, X_val, y_tr, y_val))
print('XGBoost \t-', get_scores(model_xgb, X_tr, X_val, y_tr, y_val))
# Out:
# Random Forest 	- train: 0.9889, valid: 0.798
# XGBoost 	- train: 0.9754, valid: 0.8037

# %% [markdown]
# ##### 4.4 하이퍼 파라미터 튜닝

# %%
model_xbg1 = XGBClassifier(n_estimators=50, max_depth=3, min_child_weight=1)
model_xbg1.fit(X_tr, y_tr)

model_xbg2 = XGBClassifier(n_estimators=50, max_depth=5, min_child_weight=1)
model_xbg2.fit(X_tr, y_tr)

model_xbg3 = XGBClassifier(n_estimators=50, max_depth=3, min_child_weight=2)
model_xbg3.fit(X_tr, y_tr)

model_xbg4 = XGBClassifier(n_estimators=50, max_depth=5, min_child_weight=2)
model_xbg4.fit(X_tr, y_tr)

print('model_xbg1 \t-', get_scores(model_xbg1, X_tr, X_val, y_tr, y_val))
print('model_xbg2 \t-', get_scores(model_xbg2, X_tr, X_val, y_tr, y_val))
print('model_xbg3 \t-', get_scores(model_xbg3, X_tr, X_val, y_tr, y_val))
print('model_xbg4 \t-', get_scores(model_xbg4, X_tr, X_val, y_tr, y_val))
# Out:
# model_xbg1 	- train: 0.9001, valid: 0.7903
# model_xbg2 	- train: 0.9475, valid: 0.8024
# model_xbg3 	- train: 0.8959, valid: 0.7847
# model_xbg4 	- train: 0.9372, valid: 0.8043

# %% [markdown]
# ##### 4.5 최종 결과값 생성

# %%
pred = model_xbg2.predict_proba(X_test[COL_NUM + COL_CAT])[:, 1]
result = pd.DataFrame({'ID': X_test.ID, 'pred': pred})
print(result.head())
# Out:
#      ID      pred
# 0  1569  0.472331
# 1  1344  0.964107
# 2  1429  0.058364
# 3   896  0.205212
# 4   101  0.969734

# %%
## 최종 결과 확인 후 to_csv 함수로 제출
# result.to_csv('003000000.csv', index=False)

# %% [markdown]
# # 4회 기출문제

# %% [markdown]
# ## 제 1유형 문제

# %%
# 소스 및 데이터 동기화
# !git clone https://github.com/AnalyticsKnight/yemoonsaBigdata/
# Out:
# Cloning into 'yemoonsaBigdata'...
# remote: Enumerating objects: 709, done.
# remote: Counting objects: 100% (346/346), done.
# remote: Compressing objects: 100% (231/231), done.
# remote: Total 709 (delta 156), reused 237 (delta 115), pack-reused 363 (from 1)
# Receiving objects: 100% (709/709), 11.46 MiB | 8.58 MiB/s, done.
# Resolving deltas: 100% (341/341), done.
# Updating files: 100% (173/173), done.

# %% [markdown]
# ### 문1) 다음의 (아래와 같은) 리스트가 주어졌다.

# %%
# 데이터 확인하기
lst = [2, 3, 3.2, 5, 7.5, 10, 11.8, 12, 23, 25, 31.5, 34]

# %% [markdown]
# #### 1.1 제 1 사분위수, 3 사분위수 구하기

# %%
import numpy as np

q1 = np.quantile(lst, 0.25)
q3 = np.quantile(lst, 0.75)
print(q1)
print(q3)
# Out:
# 4.55
# 23.5

# %% [markdown]
# #### 1.2 두 값의 차이의 절댓값 구하기

# %%
diff = abs(q3 - q1)
print(diff)
# Out:
# 18.95

# %% [markdown]
# #### 1.3 위의 값에서 소수점 버리고 정수로 출력

# %%
result = int(diff)
result
# Out:
# 18

# %% [markdown]
# ### 문2) 다음의 페이스북 데이터셋에서 love(num_loves) 반응과 wow(num_wows) 반응을 긍정인 반응이라고 할때/ 전체반응(num_reaction) 중 긍정의 반응 수가 차지하는 비율을 구하시오./ 그 비율이 0.5보다 작고,/ 0.4보다 큰/ 비디오 유형에 해당하는 건수를 구하시오. (p283)

# %%
import pandas as pd

df = pd.read_csv('/content/yemoonsaBigdata/datasets/Part5/402_facebook.csv')
df.head()
# Out:
#                           status_id status_type  num_reactions  num_comments  \
# 0  246675545449582_1649696485147474       video            529           512
# 1  246675545449582_1649426988507757       photo            150             0
# 2  246675545449582_1648730588577397       video            227           236
# 3  246675545449582_1648576705259452       photo            111             0
# 4  246675545449582_1645700502213739       photo            213             0
#
#    num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0         262        432         92         3          1         1           0
# 1           0        150          0         0          0         0           0
# 2          57        204         21         1          1         0           0
# 3           0        111          0         0          0         0           0
# 4           0        204          9         0          0         0           0

# %%
print(df.shape)
df.info()
# Out:
# (7050, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_id      7050 non-null   object
#  1   status_type    7050 non-null   object
#  2   num_reactions  7050 non-null   int64
#  3   num_comments   7050 non-null   int64
#  4   num_shares     7050 non-null   int64
#  5   num_likes      7050 non-null   int64
#  6   num_loves      7050 non-null   int64
#  7   num_wows       7050 non-null   int64
#  8   num_hahas      7050 non-null   int64
#  9   num_sads       7050 non-null   int64
#  10  num_angrys     7050 non-null   int64
# dtypes: int64(9), object(2)
# memory usage: 606.0+ KB

# %% [markdown]
# #### 2.1 긍정적인 반응 비율 계산하기

# %%
df['positive'] = df['num_loves'] + df['num_wows']
df['pos_prop'] = df['positive'] / df['num_reactions']
df['pos_prop'].describe()
# Out:
# count    6929.000000
# mean        0.049604
# std         0.101727
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.040000
# max         1.000000
# Name: pos_prop, dtype: float64

# %% [markdown]
# #### 2.2 문제 조건에 해당하는 데이터 추출하기

# %%
# status_type 의 종류 확인하기
df['status_type'].unique()
# Out:
# array(['video', 'photo', 'link', 'status'], dtype=object)

# %%
rst_df = df[(df['pos_prop'] > 0.4) & (df['pos_prop'] < 0.5) & (df['status_type'] == 'video')]
rst_df.head()
# Out:
#                             status_id status_type  num_reactions  \
# 3116  134115277150304_226952507866580       video            255
# 4624  725980084255106_838993039620476       video           1397
# 4776  614855718638584_852682288189258       video            259
# 4793  614855718638584_851581351632685       video            146
# 4812  614855718638584_850456998411787       video            184
#
#       num_comments  num_shares  num_likes  num_loves  num_wows  num_hahas  \
# 3116           926         181        142        108         0          5
# 4624           771         695        765        485       139          4
# 4776           695         263        151        106         0          2
# 4793           303         221         73         69         2          1
# 4812           530         224        101         80         0          1
#
#       num_sads  num_angrys  positive  pos_prop
# 3116         0           0       108  0.423529
# ...

# %%
result = len(rst_df)
print(result)
# Out:
# 90

# %% [markdown]
# ### 문3) Netflix 데이터셋에서/ 2018년 1월에  Netflix에 등록된 컨텐츠 중/ 'United Kingdom'이 단독제작 한/ 컨텐츠의 수를 정수로 출력하시오.

# %%
import pandas as pd

df = pd.read_csv('/content/yemoonsaBigdata/datasets/Part5/403_netflix.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
print(df.shape)
df.info()
# Out:
# (8807, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# #### 3.1 2018년 1월에 등록된 컨텐츠 추출하기

# %%
## 날짜 값 형태 확인하기
df['date_added'].head()
# Out:
# 0    September 25, 2021
# 1    September 24, 2021
# 2    September 24, 2021
# 3    September 24, 2021
# 4    September 24, 2021
# Name: date_added, dtype: object

# %%
df['date_added'].unique()
# Out:
# array(['September 25, 2021', 'September 24, 2021', 'September 23, 2021',
#        ..., 'December 6, 2018', 'March 9, 2016', 'January 11, 2020'],
#       dtype=object)

# %%
rst_df = df[df['date_added'].str.contains('January') & df['date_added'].str.contains('2018')]
rst_df.head()
# Out:
#      show_id     type                                              title  \
# 5055   s5056    Movie                               Expedition Happiness
# 5056   s5057    Movie  Jerry Seinfeld: I'm Telling You for the Last Time
# 5057   s5058  TV Show                                        Retribution
# 5058   s5059    Movie                                         Holy Camp!
# 5059   s5060    Movie                        A Futile and Stupid Gesture
#
#                            director  \
# 5055                   Selima Taibi
# 5056                  Marty Callner
# 5057                            NaN
# 5058  Javier Ambrossi, Javier Calvo
# 5059                     David Wain
#
#                                                    cast         country  \
# 5055                         Selima Taibi, Felix Starck         Germany
# 5056                                     Jerry Seinfeld   United States
# 5057  Georgina Campbell, Joe Dempsie, Adrian Edmonds...  United Kingdom
# ...

# %% [markdown]
# #### 3.2 영국이 단독 제작한 컨텐츠 추출하기

# %%
rst_df['country'].unique()
# Out:
# array(['Germany', 'United States', 'United Kingdom', 'Spain', 'Singapore',
#        'Mexico', 'Argentina', 'Bulgaria, United States', 'South Korea',
#        'Colombia', nan, 'United States, New Zealand', 'Japan',
#        'Canada, United States', 'Soviet Union, India', 'India',
#        'Australia, United Arab Emirates', 'Czech Republic, United States',
#        'United Kingdom, United States', 'France',
#        'United States, United Kingdom, France',
#        'United States, India, Bangladesh', 'Germany, Belgium',
#        'Canada, France, Italy, Morocco, United States', 'Nigeria',
#        'United States, Canada', 'United States, Italy',
#        'China, Hong Kong',
#        'United Kingdom, United States, Dominican Republic',
#        'India, France',
#        'Denmark, Germany, Belgium, United Kingdom, France',
#        'Brazil, India, China, United States', 'France, Belgium',
#        'New Zealand', 'Ireland, Canada, United States, United Kingdom',
# ...

# %%
rst_df = rst_df[rst_df['country'] == 'United Kingdom']
rst_df.head()
# Out:
#      show_id     type                                       title  \
# 5057   s5058  TV Show                                 Retribution
# 5074   s5075    Movie                         Bad Day for the Cut
# 5097   s5098  TV Show                                    Lovesick
# 7398   s7399    Movie  Manolo: The Boy Who Made Shoes for Lizards
# 8357   s8358  TV Show                            The Inbetweeners
#
#              director                                               cast  \
# 5057              NaN  Georgina Campbell, Joe Dempsie, Adrian Edmonds...
# 5074      Chris Baugh  Nigel O'Neill, Susan Lynch, Józef Pawlowski, S...
# 5097              NaN  Johnny Flynn, Antonia Thomas, Daniel Ings, Han...
# 7398  Michael Roberts  Manolo Blahnik, Anna Wintour, André Leon Talle...
# 8357              NaN  Simon Bird, James Buckley, Blake Harrison, Joe...
#
#              country        date_added  release_year rating   duration  \
# ...

# %% [markdown]
# #### 3.3 결과 출력하기

# %%
result = len(rst_df)
print(result)
# Out:
# 6

# %% [markdown]
# ## 제 2유형 문제

# %% [markdown]
# ### 문) 다음의 데이터셋에서 주어진 훈련세트를 활용해 고객이 속한 Segmentation을 예측하고 그 결과를 csv 파일로 출력하기
# - macro_f1 결과를 가지고 최종 점수가 반영됨.

# %% [markdown]
# #### (1) 데이터 불러오고 데이터 확인하기

# %%
# 데이터 파일 읽기 예제
import pandas as pd
X_test = pd.read_csv("yemoonsaBigdata/datasets/Part5/404_x_test.csv")
X_train = pd.read_csv("yemoonsaBigdata/datasets/Part5/404_x_train.csv")
y_train = pd.read_csv("yemoonsaBigdata/datasets/Part5/404_y_train.csv")

# %%
X_test.shape, X_train.shape, y_train.shape
# Out:
# ((2178, 9), (6718, 9), (6718, 2))

# %%
X_train.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  462809    Male           No   22        No  Healthcare              1.0
# 1  466315  Female          Yes   67       Yes    Engineer              1.0
# 2  461735    Male          Yes   67       Yes      Lawyer              0.0
# 3  461319    Male          Yes   56        No      Artist              0.0
# 4  460156    Male           No   32       Yes  Healthcare              1.0
#
#   Spending_Score  Family_Size
# 0            Low          4.0
# 1            Low          1.0
# 2           High          2.0
# 3        Average          2.0
# 4            Low          3.0

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6718 entries, 0 to 6717
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               6718 non-null   int64
#  1   Gender           6718 non-null   object
#  2   Ever_Married     6718 non-null   object
#  3   Age              6718 non-null   int64
#  4   Graduated        6718 non-null   object
#  5   Profession       6718 non-null   object
#  6   Work_Experience  6718 non-null   float64
#  7   Spending_Score   6718 non-null   object
#  8   Family_Size      6718 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 472.5+ KB

# %%
# 결측치 확인
X_train.isnull().sum()
# Out:
# ID                 0
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Profession         0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# dtype: int64

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6718 entries, 0 to 6717
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            6718 non-null   int64
#  1   Segmentation  6718 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 105.1+ KB

# %% [markdown]
# #### (2) 변수 구분

# %%
# ID: 불필요한 변수
# Age, Work_Experience, Family_Size: 수치형 변수
# Gender, Ever_Married, Graduated, Profession, Spending_Score: 범주형 변수
# Segmentation: 종속 변수
COL_DEL = ['ID']
COL_NUM = ['Age', 'Work_Experience', 'Family_Size']
COL_CAT = ['Gender', 'Ever_Married', 'Graduated', 'Profession', 'Spending_Score']
COL_Y = ['Segmentation']

# %% [markdown]
# #### (3) 데이터 모형 구축

# %% [markdown]
# ##### 3-1 데이터 분할

# %%
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(X_train[COL_NUM + COL_CAT],
                                            y_train[COL_Y],
                                            test_size=0.3,
                                            stratify=y_train[COL_Y])

# %%
X_tr.head()
# Out:
#       Age  Work_Experience  Family_Size  Gender Ever_Married Graduated  \
# 3693   38              0.0          2.0    Male           No       Yes
# 3159   45              4.0          4.0  Female          Yes       Yes
# 2815   47              1.0          2.0  Female          Yes       Yes
# 1896   30             14.0          3.0    Male           No       Yes
# 6172   27              6.0          2.0  Female          Yes        No
#
#          Profession Spending_Score
# 3693         Artist            Low
# 3159         Artist        Average
# 2815  Entertainment            Low
# 1896  Entertainment            Low
# 6172  Entertainment           High

# %%
y_tr.head()
# Out:
#      Segmentation
# 3693            B
# 3159            C
# 2815            B
# 1896            D
# 6172            B

# %% [markdown]
# ##### 3-2 수치형 변수 - 데이터 스케일링

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_tr[COL_NUM])

X_tr[COL_NUM] = scaler.transform(X_tr[COL_NUM])
X_val[COL_NUM] = scaler.transform(X_val[COL_NUM])
X_test[COL_NUM] = scaler.transform(X_test[COL_NUM])

# %%
X_tr[COL_NUM].head()
# Out:
#            Age  Work_Experience  Family_Size
# 3693 -0.328251        -0.777371    -0.559615
# 3159  0.095105         0.398596     0.757357
# 2815  0.216065        -0.483379    -0.559615
# 1896 -0.812088         3.338512     0.098871
# 6172 -0.993526         0.986579    -0.559615

# %% [markdown]
# ##### 3-3 범주형 변수 - 데이터 인코딩

# %%
from sklearn.preprocessing import LabelEncoder

X = pd.concat([X_train[COL_CAT], X_test[COL_CAT]])

for col in COL_CAT:
    le = LabelEncoder()
    le.fit(X[col])
    X_tr[col] = le.transform(X_tr[col])
    X_val[col] = le.transform(X_val[col])
    X_test[col] = le.transform(X_test[col])

    # 각 변수의 클래스 확인
    print(col)
    print(le.classes_)
    print('\n')
# Out:
# Gender
# ['Female' 'Male']
#
#
# Ever_Married
# ['No' 'Yes']
#
#
# Graduated
# ['No' 'Yes']
#
#
# Profession
# ['Artist' 'Doctor' 'Engineer' 'Entertainment' 'Executive' 'Healthcare'
#  'Homemaker' 'Lawyer' 'Marketing']
#
#
# Spending_Score
# ['Average' 'High' 'Low']

# %%
X_tr[COL_CAT].head()
# Out:
#       Gender  Ever_Married  Graduated  Profession  Spending_Score
# 3693       1             0          1           0               2
# 3159       0             1          1           0               0
# 2815       0             1          1           3               2
# 1896       1             0          1           3               2
# 6172       0             1          0           3               1

# %% [markdown]
# ##### 3-4 모형 학습

# %%
## XGBoost 최신 버전에서 발생하는 y 데이터의 Label오류 해결을 위한 추가 코드
y_le = LabelEncoder()
y_le.fit(y_train[COL_Y])

y_tr = y_le.transform(y_tr)
y_val = y_le.transform(y_val)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
## 1) 랜덤 포레스트
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier(random_state=123)
model_rf.fit(X_tr, y_tr)

## 2) XGBoost
from xgboost import XGBClassifier

model_xgb = XGBClassifier()
model_xgb.fit(X_tr, y_tr)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %% [markdown]
# #### (4) 데이터 모형 평가

# %% [markdown]
# ##### 4.1 검증 데이터로 예측값 생성

# %%
y_predRF = model_rf.predict(X_val)
y_predXGB = model_xgb.predict(X_val)

# %% [markdown]
# ##### 4.2 평가지표 구하기

# %%
## 답안 채점 기준인 macro f1 score 사용
from sklearn.metrics import f1_score

score_rf = f1_score(y_val, y_predRF, average='macro')
score_xgb = f1_score(y_val, y_predXGB, average='macro')

print('RandomForest: ', score_rf)
print('XGBoost: ', score_xgb)
# Out:
# RandomForest:  0.4734482882196724
# XGBoost:  0.5092449196990989

# %%
## 참고 - metric 종류 확인
# import sklearn.metrics
# print(help(sklearn.metrics)) # 써야할 함수 명을 아예 모를 때

# %% [markdown]
# ##### 4.3 학습, 검증 성능 확인 함수

# %%
def get_scores(model, X_tr, X_val, y_tr, y_val):
    y_tr_pred = model.predict(X_tr)
    y_val_pred = model.predict(X_val)
    tr_score = f1_score(y_tr, y_tr_pred, average='macro')
    val_score = f1_score(y_val, y_val_pred, average='macro')

    return f'train: {round(tr_score, 4)}, valid: {round(val_score, 4)}'

# %%
print('RandomForest: ', get_scores(model_rf, X_tr, X_val, y_tr, y_val))
print('XGBoost: ', get_scores(model_xgb, X_tr, X_val, y_tr, y_val))
# Out:
# RandomForest:  train: 0.9464, valid: 0.4734
# XGBoost:  train: 0.784, valid: 0.5092

# %% [markdown]
# ##### 4.4 하이퍼 파라미터 튜닝

# %%
model_xgb2 = XGBClassifier(n_estimators=50, max_depth=3, min_child_weight=1, random_state=123)
model_xgb2.fit(X_tr, y_tr)

model_xgb3 = XGBClassifier(n_estimators=50, max_depth=3, min_child_weight=2, random_state=123)
model_xgb3.fit(X_tr, y_tr)

model_xgb4 = XGBClassifier(n_estimators=50, max_depth=5, min_child_weight=1, random_state=123)
model_xgb4.fit(X_tr, y_tr)

model_xgb5 = XGBClassifier(n_estimators=100, max_depth=5, min_child_weight=1, random_state=123)
model_xgb5.fit(X_tr, y_tr)

print('XGBoost2: ', get_scores(model_xgb2, X_tr, X_val, y_tr, y_val))
print('XGBoost3: ', get_scores(model_xgb3, X_tr, X_val, y_tr, y_val))
print('XGBoost4: ', get_scores(model_xgb4, X_tr, X_val, y_tr, y_val))
print('XGBoost5: ', get_scores(model_xgb5, X_tr, X_val, y_tr, y_val))
# Out:
# XGBoost2:  train: 0.5697, valid: 0.5319
# XGBoost3:  train: 0.5666, valid: 0.5361
# XGBoost4:  train: 0.648, valid: 0.5285
# XGBoost5:  train: 0.7129, valid: 0.5174

# %% [markdown]
# ##### 4.5 최종 결과값 생성

# %%
pred = model_xgb.predict(X_test[COL_NUM + COL_CAT])

## XGBoost 최신 버전에서 발생하는 y 데이터의 Label오류 해결을 위한 추가 코드
pred = y_le.inverse_transform(pred)

result = pd.DataFrame({'ID': X_test.ID, 'Segmentation': pred})
print(result.head())
# Out:
#        ID Segmentation
# 0  458989            B
# 1  458994            D
# 2  459000            C
# 3  459003            C
# 4  459005            B

# %%
## 최종 결과 확인 후 to_csv 함수로 제출
# result.to_csv('003000000.csv', index=False)

# %% [markdown]
# # 5회 기출문제

# %%
# !git clone https://github.com/AnalyticsKnight/yemoonsaBigdata/
# Out:
# Cloning into 'yemoonsaBigdata'...
# remote: Enumerating objects: 709, done.
# remote: Counting objects: 100% (348/348), done.
# remote: Compressing objects: 100% (233/233), done.
# remote: Total 709 (delta 157), reused 237 (delta 115), pack-reused 361 (from 1)
# Receiving objects: 100% (709/709), 11.46 MiB | 9.33 MiB/s, done.
# Resolving deltas: 100% (341/341), done.
# Updating files: 100% (173/173), done.

# %% [markdown]
# ## 제 1유형 문제

# %% [markdown]
# ### 문1.1) trash bag 데이터셋은 지역별 종량제 봉투 가격이다./ 가격 컬럼에서 해당 용량의 종량제 봉투가 존재하면/ 가격을 값으로 존재하지 않으면 0으로 표시/ 용도가 음식물 쓰레기이고/ 사용대상이 가정용인/ 2L 봉투 가격의 평균을 구하시오(소수점을 버린 후 정수로 출력)

# %%
import pandas as pd

df = pd.read_csv('/content/yemoonsaBigdata/datasets/Part5/501_trash_bag.csv', encoding='cp949')
df.head()
# Out:
#    시도명 시군구명       종류 처리방식      용도 사용대상  1L가격  1.5L가격  2L가격  2.5L가격  ...  5L가격  \
# 0  강원도  강릉시     규격봉투  매립용   생활쓰레기   기타     0       0     0       0  ...   130
# 1  강원도  강릉시  재사용규격봉투  매립용   생활쓰레기   기타     0       0     0       0  ...     0
# 2  강원도  고성군     규격봉투  소각용   생활쓰레기  가정용     0       0     0       0  ...   140
# 3  강원도  고성군     규격봉투  소각용  음식물쓰레기  가정용     0       0    60       0  ...   120
# 4  강원도  고성군   특수규격마대  매립용   생활쓰레기  가정용     0       0     0       0  ...     0
#
#    10L가격  20L가격  30L가격  50L가격  60L가격  75L가격  100L가격  120L가격  125L가격
# 0    270    520      0   1250      0   1880       0       0       0
# 1    270    520      0      0      0      0       0       0       0
# 2    260    500      0   1220      0      0    2410       0       0
# 3      0      0      0      0      0      0       0       0       0
# 4      0      0      0   1540      0      0       0       0       0
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### 1.2 용도, 사용대상 기준으로 데이터 추출하기

# %%
df_filtered = df[(df['용도']=='음식물쓰레기') & (df['사용대상']=='가정용')]
df_filtered.head()
# Out:
#     시도명 시군구명    종류 처리방식      용도 사용대상  1L가격  1.5L가격  2L가격  2.5L가격  ...  5L가격  \
# 3   강원도  고성군  규격봉투  소각용  음식물쓰레기  가정용     0       0    60       0  ...   120
# 8   강원도  삼척시  규격봉투  매립용  음식물쓰레기  가정용     0       0     0       0  ...    80
# 9   강원도  양구군  규격봉투  매립용  음식물쓰레기  가정용     0       0    50       0  ...   120
# 12  강원도  양양군  규격봉투   기타  음식물쓰레기  가정용     0       0    40       0  ...    90
# 16  강원도  영월군  규격봉투  매립용  음식물쓰레기  가정용     0       0     0       0  ...   110
#
#     10L가격  20L가격  30L가격  50L가격  60L가격  75L가격  100L가격  120L가격  125L가격
# 3       0      0      0      0      0      0       0       0       0
# 8     150    290      0      0      0      0       0       0       0
# 9     210    400      0      0      0      0       0       0       0
# 12    170    340      0      0      0      0       0       0       0
# 16    180    350      0    900      0   1350       0       0       0
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### 1.3 2L 봉투가 존재하는 데이터 추출

# %%
rst_df = df_filtered[df_filtered['2L가격'] != 0]
rst_df.head()
# Out:
#     시도명 시군구명    종류 처리방식      용도 사용대상  1L가격  1.5L가격  2L가격  2.5L가격  ...  5L가격  \
# 3   강원도  고성군  규격봉투  소각용  음식물쓰레기  가정용     0       0    60       0  ...   120
# 9   강원도  양구군  규격봉투  매립용  음식물쓰레기  가정용     0       0    50       0  ...   120
# 12  강원도  양양군  규격봉투   기타  음식물쓰레기  가정용     0       0    40       0  ...    90
# 20  강원도  원주시  규격봉투   기타  음식물쓰레기  가정용     0       0    80       0  ...   170
# 33  강원도  춘천시  규격봉투  매립용  음식물쓰레기  가정용    40       0    50       0  ...   140
#
#     10L가격  20L가격  30L가격  50L가격  60L가격  75L가격  100L가격  120L가격  125L가격
# 3       0      0      0      0      0      0       0       0       0
# 9     210    400      0      0      0      0       0       0       0
# 12    170    340      0      0      0      0       0       0       0
# 20    320    680      0   1690      0      0       0       0       0
# 33    230    470      0      0      0      0       0       0       0
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### 1.3 결과 출력

# %%
result = int(rst_df['2L가격'].mean())
result
# Out:
# 119

# %% [markdown]
# ### 문1.2) BMI 지수 데이터 셋에서 비만도가 정상인 인원수와/ 과체중인 인원수/의 차이/를 정수로 출력하시오.

# %%
import pandas as pd

df = pd.read_csv('/content/yemoonsaBigdata/datasets/Part5/502_bmi.csv')
df.head()
# Out:
#    Gender  Height  Weight
# 0    Male     174      96
# 1    Male     189      87
# 2  Female     185     110
# 3  Female     195     104
# 4    Male     149      61

# %% [markdown]
# ##### 2.1 bmi지수 구하기

# %%
df['Height_m'] = df['Height'] / 100
df['BMI'] = df['Weight'] / (df['Height_m']**2)
df.head()
# Out:
#    Gender  Height  Weight  Height_m        BMI
# 0    Male     174      96      1.74  31.708284
# 1    Male     189      87      1.89  24.355421
# 2  Female     185     110      1.85  32.140248
# 3  Female     195     104      1.95  27.350427
# 4    Male     149      61      1.49  27.476240

# %% [markdown]
# ##### 2.2 비만도 구하기

# %%
n1 = len(df[(df['BMI'] >= 18.5) & (df['BMI'] < 23)])
n2 = len(df[(df['BMI'] >= 23) & (df['BMI'] < 25)])
n1, n2
# Out:
# (47, 19)

# %% [markdown]
# ##### 2.3 결과 출력

# %%
result = n1 - n2
result
# Out:
# 28

# %% [markdown]
# ### 문1.3) student 데이터셋에서 순전입학생(총 전입학생수 - 총 전출학생수)/ 가 가장 많은 학교의/ 전체학생수?

# %%
import pandas as pd

df = pd.read_csv('/content/yemoonsaBigdata/datasets/Part5/503_students.csv', encoding='cp949')
df.head()
# Out:
#   학교  학년  총 전입학생  총 전출학생  전체 학생 수
# 0  A   1       9       1      222
# 1  A   2      13       4      148
# 2  A   3       8       7      196
# 3  B   1       7       5      171
# 4  B   2       9       1      216

# %%
df.shape
# Out:
# (24, 5)

# %% [markdown]
# #### 3.1 순 전입학생 수 구하기

# %%
df['순 전입학생 수'] = df['총 전입학생'] - df['총 전출학생']
df.head()
# Out:
#   학교  학년  총 전입학생  총 전출학생  전체 학생 수  순 전입학생 수
# 0  A   1       9       1      222         8
# 1  A   2      13       4      148         9
# 2  A   3       8       7      196         1
# 3  B   1       7       5      171         2
# 4  B   2       9       1      216         8

# %% [markdown]
# #### 3.2 학교별 총 순 전입생 수, 전체 학생 수 계산

# %%
rst_df = df.groupby(['학교'])[['순 전입학생 수', '전체 학생 수']].sum()
rst_df.head()
# Out:
#     순 전입학생 수  전체 학생 수
# 학교
# A         18      566
# B         13      588
# C         -9      528
# D          7      548
# E         14      603

# %% [markdown]
# #### 3.3 결과 출력하기

# %%
result = rst_df.loc[rst_df['순 전입학생 수']==max(rst_df['순 전입학생 수']), '전체 학생 수']
result
# Out:
# 학교
# A    566
# Name: 전체 학생 수, dtype: int64

# %% [markdown]
# ## 제 2유형 문제

# %% [markdown]
# ### 문) 다음의 Used Car 데이터셋에서 훈련 데이터를 활용해서 중교차의 판매가격을 예측하고/ 결과를 csv 파일로 제출하시오.(평가결과는 rmse를 사용)

# %%
# 데이터 파일 읽기 예제
import pandas as pd
X_train = pd.read_csv("yemoonsaBigdata/datasets/Part5/504_x_train.csv")
X_test = pd.read_csv("yemoonsaBigdata/datasets/Part5/504_x_test.csv")
y_train = pd.read_csv("yemoonsaBigdata/datasets/Part5/504_y_train.csv")

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((7468, 9), (3200, 9), (7468, 2))

# %%
X_train.head()
# Out:
#    id model  year transmission  mileage fuelType  tax   mpg  engineSize
# 0   1    A1  2019    Automatic     3500   Petrol  145  40.9         2.0
# 1   2   RS4  2020    Semi-Auto     2500   Petrol  145  28.8         2.9
# 2   3    A8  2019    Semi-Auto      500   Diesel  145  40.4         3.0
# 3   4    Q5  2019    Semi-Auto     5089   Diesel  150  38.2         2.0
# 4   5    A5  2020    Semi-Auto     4951   Diesel  145  51.4         2.0

# %% [markdown]
# #### 2.데이터 전처리

# %% [markdown]
# ##### 2.1 데이터 확인하기

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7468 entries, 0 to 7467
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            7468 non-null   int64
#  1   model         7468 non-null   object
#  2   year          7468 non-null   int64
#  3   transmission  7468 non-null   object
#  4   mileage       7468 non-null   int64
#  5   fuelType      7468 non-null   object
#  6   tax           7468 non-null   int64
#  7   mpg           7468 non-null   float64
#  8   engineSize    7468 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 525.2+ KB

# %%
X_train.columns
# Out:
# Index(['id', 'model', 'year', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %%
y_train.columns
# Out:
# Index(['id', 'price'], dtype='object')

# %% [markdown]
# ##### 2.2 변수별 결측치 수 확인

# %%
X_train.isnull().sum()
# Out:
# id              0
# model           0
# year            0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
y_train.isnull().sum()
# Out:
# id       0
# price    0
# dtype: int64

# %% [markdown]
# ##### 2.3 변수 구분

# %%
COL_DEL = ['ID']
COL_NUM = ['year', 'mileage', 'tax', 'mpg', 'engineSize']
COL_CAT = ['model', 'transmission', 'fuelType']
COL_Y = ['price']

# %% [markdown]
# #### 3.데이터 모형 구축

# %% [markdown]
# ##### 3.1 데이터 분할

# %%
from sklearn.model_selection import train_test_split
X_tr, X_val, y_tr, y_val = train_test_split(X_train[COL_NUM+COL_CAT],
                                            y_train[COL_Y],
                                            test_size=0.3,
                                            random_state=123)

# %%
X_tr.head()
# Out:
#       year  mileage  tax    mpg  engineSize model transmission fuelType
# 261   2019     3139  145   33.2         3.0    Q7    Automatic   Diesel
# 1084  2020     1000  145   47.1         2.0    A5    Semi-Auto   Diesel
# 1025  2019       28  145   44.8         1.5    A1    Semi-Auto   Petrol
# 591   2019     3215  145   38.7         2.0    A4    Automatic   Petrol
# 44    2020     7500  135  141.3         1.4    A3    Semi-Auto   Hybrid

# %%
y_tr.head()
# Out:
#       price
# 261   49990
# 1084  31000
# 1025  20450
# 591   26470
# 44    32495

# %% [markdown]
# ##### 3.2 수치형 변수 - 데이터 스케일링

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_tr[COL_NUM])

X_tr[COL_NUM] = scaler.transform(X_tr[COL_NUM])
X_val[COL_NUM] = scaler.transform(X_val[COL_NUM])
X_test[COL_NUM] = scaler.transform(X_test[COL_NUM])

# %%
X_tr[COL_NUM].head()
# Out:
#           year   mileage       tax       mpg  engineSize
# 261   0.883650 -0.933474  0.287777 -1.404072    1.824073
# 1084  1.345765 -1.024529  0.287777 -0.302377    0.129545
# 1025  0.883650 -1.065906  0.287777 -0.484672   -0.717719
# 591   0.883650 -0.930239  0.287777 -0.968150    0.129545
# 44    1.345765 -0.747831  0.136311  7.163781   -0.887171

# %% [markdown]
# ##### 3.3 범주형 변수 - 데이터 인코딩

# %%
from sklearn.preprocessing import LabelEncoder

X = pd.concat([X_train[COL_CAT], X_test[COL_CAT]])

for col in COL_CAT:
    le = LabelEncoder()
    le.fit(X[col])
    X_tr[col] = le.transform(X_tr[col])
    X_val[col] = le.transform(X_val[col])
    X_test[col] = le.transform(X_test[col])

    # 각 변수의 클래스 확인
    print(col)
    print(le.classes_)
    print('\n')
# Out:
# model
# [' A1' ' A2' ' A3' ' A4' ' A5' ' A6' ' A7' ' A8' ' Q2' ' Q3' ' Q5' ' Q7'
#  ' Q8' ' R8' ' RS3' ' RS4' ' RS5' ' RS6' ' RS7' ' S3' ' S4' ' S5' ' S8'
#  ' SQ5' ' SQ7' ' TT']
#
#
# transmission
# ['Automatic' 'Manual' 'Semi-Auto']
#
#
# fuelType
# ['Diesel' 'Hybrid' 'Petrol']

# %%
X_tr[COL_CAT].head()
# Out:
#       model  transmission  fuelType
# 261      11             0         0
# 1084      4             2         0
# 1025      0             2         2
# 591       3             0         2
# 44        2             2         1

# %% [markdown]
# ##### 3.4 모형 학습

# %%
## 1) 랜덤 포레스트(회귀 문제)
from sklearn.ensemble import RandomForestRegressor

model_rf = RandomForestRegressor(random_state=123)
model_rf.fit(X_tr, y_tr)

## 2) XGBoost
from xgboost import XGBRegressor

model_xgb = XGBRegressor(random_state=123)
model_xgb.fit(X_tr, y_tr)

## 3) LightGBM
import lightgbm as lgb

model_lgb = lgb.LGBMRegressor(random_state=123, verbose=-1)
model_lgb.fit(X_tr, y_tr)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# LGBMRegressor(random_state=123, verbose=-1)

# %% [markdown]
# #### 4.데이터 모형 평가

# %% [markdown]
# ##### 4.1 검증 데이터로 예측값 생성

# %%
y_pred_rf = model_rf.predict(X_val)
y_pred_xgb = model_xgb.predict(X_val)
y_pred_lgb = model_lgb.predict(X_val)

# %% [markdown]
# ##### 4.2 평가지표 구하기

# %%
## 답안 채점 기준인 rmse 사용
import numpy as np
from sklearn.metrics import mean_squared_error

def cal_rmse(actual, pred):
    return np.sqrt(mean_squared_error(actual, pred))

score_rf = cal_rmse(y_val, y_pred_rf)
score_xgb = cal_rmse(y_val, y_pred_xgb)
score_lgb = cal_rmse(y_val, y_pred_lgb)

print('RandomForest: ', score_rf)
print('XGBoost: ', score_xgb)
print('LightGBM : ', score_lgb)
# Out:
# RandomForest:  2579.8330150177558
# XGBoost:  2762.919470415307
# LightGBM :  2653.5515240001537

# %%
def get_scores(model, X_tr, X_val, y_tr, y_val):

  y_tr_pred = model.predict(X_tr)
  y_val_pred = model.predict(X_val)
  tr_score = cal_rmse(y_tr, y_tr_pred)
  val_score = cal_rmse(y_val, y_val_pred)

  return f'train: {round(tr_score, 4)}, valid: {round(val_score, 4)}'

# %%
print('Random Forest \t-', get_scores(model_rf, X_tr, X_val, y_tr, y_val))
print('XGBoost \t-', get_scores(model_xgb, X_tr, X_val, y_tr, y_val))
# Out:
# Random Forest 	- train: 984.7356, valid: 2579.833
# XGBoost 	- train: 1254.1299, valid: 2762.9195

# %%
from xgboost import XGBRegressor

# 모델 설정 리스트
params_list = [
    {'n_estimators': 50, 'max_depth': 5, 'min_child_weight': 2},
    {'n_estimators': 50, 'max_depth': 10, 'min_child_weight': 2},
    {'n_estimators': 100, 'max_depth': 5, 'min_child_weight': 1},
    {'n_estimators': 100, 'max_depth': 10, 'min_child_weight': 2}
]

# 모델 저장 딕셔너리
models = {}

# 반복문을 사용한 모델 생성 및 학습
for i, params in enumerate(params_list, start=2):
    model_name = f"model_xgb{i}"
    models[model_name] = XGBRegressor(objective='reg:squarederror', random_state=123, **params)
    models[model_name].fit(X_tr, y_tr)

# 결과 확인
models
# Out:
# {'model_xgb2': XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=2, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=50, n_jobs=None,
#               num_parallel_tree=None, random_state=123, ...),
#  'model_xgb3': XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
# ...

# %%
print('XGBoost2 \t-', get_scores(model_xgb2, X_tr, X_val, y_tr, y_val))
print('XGBoost3 \t-', get_scores(model_xgb3, X_tr, X_val, y_tr, y_val))
print('XGBoost4 \t-', get_scores(model_xgb4, X_tr, X_val, y_tr, y_val))
print('XGBoost5 \t-', get_scores(model_xgb5, X_tr, X_val, y_tr, y_val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-ac792de4b28b> in <cell line: 0>()
# ----> 1 print('XGBoost2 \t-', get_scores(model_xgb2, X_tr, X_val, y_tr, y_val))
#       2 print('XGBoost3 \t-', get_scores(model_xgb3, X_tr, X_val, y_tr, y_val))
#       3 print('XGBoost4 \t-', get_scores(model_xgb4, X_tr, X_val, y_tr, y_val))
#       4 print('XGBoost5 \t-', get_scores(model_xgb5, X_tr, X_val, y_tr, y_val))
#
# NameError: name 'model_xgb2' is not defined
