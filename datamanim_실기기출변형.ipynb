# %% [markdown]
# <a href="https://colab.research.google.com/github/va4756/yemoon_bigdata_test/blob/main/datamanim_%EC%8B%A4%EA%B8%B0%EA%B8%B0%EC%B6%9C%EB%B3%80%ED%98%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 제 7회 기출 문제 변형

# %% [markdown]
# ## 7-1.작업 1유형

# %%
# DataUrl = https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p1.csv 데이터 출처 : 자체 제작
# 데이터 설명 : 학생 15명의 국어,수학,영어,과학 시험 점수이다. 각 학생은 4과목 중 3과목을 선택해서 시험봤다.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p1.csv')
df.head()
# Out:
#      학생    국어    수학    영어    과학
# 0  ID_0  63.0   NaN  79.0  84.0
# 1  ID_1  91.0  93.0   NaN  73.0
# 2  ID_2  59.0  55.0   NaN  56.0
# 3  ID_3  71.0  83.0  82.0   NaN
# 4  ID_4  62.0  72.0  56.0   NaN

# %%
print(df.shape)
df.info()
# Out:
# (15, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   학생      15 non-null     object
#  1   국어      13 non-null     float64
#  2   수학      12 non-null     float64
#  3   영어      11 non-null     float64
#  4   과학      9 non-null      float64
# dtypes: float64(4), object(1)
# memory usage: 732.0+ bytes

# %% [markdown]
# ### 문1-1) 국어,수학,영어,과학 과목 중 가장 많은 학생들이 응시한 시험을 선택하고 해당과목의 점수를 표준화 했을 때 가장 큰 표준화 점수를 구하여라

# %%
import numpy as np
sub = df.iloc[:, 1:].count().idxmax()
print(sub)
# Out:
# 국어

# %%
std = df[sub]
std
# Out:
# 0     63.0
# 1     91.0
# 2     59.0
# 3     71.0
# 4     62.0
# 5      NaN
# 6     83.0
# 7     85.0
# 8     96.0
# 9     79.0
# 10    68.0
# 11    61.0
# 12    86.0
# 13     NaN
# 14    79.0
# Name: 국어, dtype: float64

# %%
r = (df[sub] - df[sub].mean()) / df[sub].std(ddof=0)  # 모표준편차 ddof=0
result = r.max()
print(result)  # 최종결과
# Out:
# 1.713855688712825

# %%
# 다른 방법: scipy를 이용
from scipy import stats
result = stats.zscore(df[sub].dropna()).max()
result
# Out:
# 1.713855688712825

# %%
# DataUrl = https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p2.csv
# 데이터 출처 : 자체제작 32개 변수의 수치값

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p2_.csv')
df.head()
# Out:
#       var_1     var_2     var_3     var_4     var_5     var_6     var_7  \
# 0 -0.335864 -2.425701  0.452851 -1.381924 -0.425591 -1.461498 -0.417082
# 1  0.803535 -0.699433  0.095579  0.788053 -0.267674 -0.370746  0.636034
# 2 -0.408470 -0.361105 -0.857278  0.338294  2.317821 -0.099928  0.557053
# 3 -0.690599  0.777928 -0.079963  0.164086  1.721702  0.146761 -0.988636
# 4  0.179819 -0.668267  0.381849 -0.884196  0.758519 -1.026190  0.986227
#
#       var_8     var_9    var_10  ...    var_23    var_24    var_25    var_26  \
# 0 -0.944226 -0.351224  1.474046  ...  1.715714  0.300227  0.439828 -0.094772
# 1 -1.674584 -0.058465 -1.188973  ... -1.348879 -0.899480 -1.271886  0.333734
# 2 -0.847932  0.973471  0.101203  ... -0.388353  0.918553 -1.984422  0.385055
# 3  0.885344  0.647053  0.674609  ...  0.337074 -1.406224 -0.699728 -0.836068
# 4 -1.663167  2.290551  0.564845  ... -0.700137 -0.153825 -1.835313  0.182131
#
#      var_27    var_28    var_29    var_30    var_31    var_32
# ...

# %%
print(df.shape)
df.info()
# Out:
# (1000, 32)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   var_1   1000 non-null   float64
#  1   var_2   1000 non-null   float64
#  2   var_3   1000 non-null   float64
#  3   var_4   1000 non-null   float64
#  4   var_5   1000 non-null   float64
#  5   var_6   1000 non-null   float64
#  6   var_7   1000 non-null   float64
#  7   var_8   1000 non-null   float64
#  8   var_9   1000 non-null   float64
#  9   var_10  1000 non-null   float64
#  10  var_11  1000 non-null   float64
#  11  var_12  1000 non-null   float64
#  12  var_13  1000 non-null   float64
#  13  var_14  1000 non-null   float64
#  14  var_15  1000 non-null   float64
#  15  var_16  1000 non-null   float64
#  16  var_17  1000 non-null   float64
#  17  var_18  1000 non-null   float64
#  18  var_19  1000 non-null   float64
#  19  var_20  1000 non-null   float64
# ...

# %% [markdown]
# ### 문1-2) 32개의 변수간 상관관계를 확인 했을 때, var_11 컬럼과 상관계수의 절댓값이 가장 큰 변수를 찾아 해당 변수의 평균값을 구하여라

# %%
corr_11 = df.corr()['var_11']
max_var = corr_11.abs().sort_values().index[-2]
result =  df[max_var].mean()
result
# Out:
# -0.06289356546077182

# %%
# DataUrl = https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p3.csv

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p3.csv')
df.head()
# Out:
#       var_1     var_2     var_3     var_4     var_5     var_6     var_7  \
# 0 -0.401584  0.007198 -0.134910 -0.419514 -0.686331 -1.174550 -0.499150
# 1  1.064622 -0.531247  0.571185 -0.762243 -1.456043  0.355432  0.880010
# 2  0.900195 -1.148496 -0.718437 -2.315266 -0.755505  0.630923  0.586027
# 3  1.199227 -0.114200  0.101536 -1.851971 -0.672844  0.796077  0.644246
# 4  0.607393  1.675917  1.063759 -0.799493 -0.959568 -0.103007 -0.245984
#
#       var_8     var_9    var_10    var_11    var_12
# 0 -0.557510  0.357347  0.844209  0.082097  0.475098
# 1  0.523183 -0.141733  0.301472  0.840299 -0.045113
# 2  0.086497 -0.381657 -1.602532  1.566340 -0.654105
# 3 -0.836296 -1.707074  0.376281  1.303967  1.228015
# 4 -0.059492  0.293592 -0.517044  0.100772  0.403833

# %%
print(df.shape)
df.info()
# Out:
# (523, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523 entries, 0 to 522
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   var_1   523 non-null    float64
#  1   var_2   523 non-null    float64
#  2   var_3   523 non-null    float64
#  3   var_4   523 non-null    float64
#  4   var_5   523 non-null    float64
#  5   var_6   523 non-null    float64
#  6   var_7   523 non-null    float64
#  7   var_8   523 non-null    float64
#  8   var_9   523 non-null    float64
#  9   var_10  523 non-null    float64
#  10  var_11  523 non-null    float64
#  11  var_12  523 non-null    float64
# dtypes: float64(12)
# memory usage: 49.2 KB

# %% [markdown]
# ### 문1-3) var_6 컬럼의 1,3사분위수 각각 IQR의 1.5배 벗어난 이상치의 숫자를 구하라

# %%
q_1 = df['var_6'].quantile(0.25)
q_3 = df['var_6'].quantile(0.75)
iqr = q_3 - q_1
max_val = q_3 + 1.5*iqr
min_val = q_1 - 1.5*iqr
outlier = df[(df['var_6'] < min_val) | (df['var_6'] > max_val)]
result = len(outlier)
result
# Out:
# 8

# %% [markdown]
# ## 7-2.작업 2유형

# %%
# 제주업종별카드이용정보 : https://www.jejudatahub.net/data/view/data/1048
# 후처리
# train = https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p2_train2.csv
# test = https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p2_test2.csv
# 종속변수 :이용금액 , 평가지표 : rmse

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p2_train2.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p2_test2.csv')

display(train.head(2))
test.head(2)
# Out:
#         ID      연월  업종명 이용자구분    성별  이용자수   이용건수        이용금액
# 0  ID_5020  202201  여관업    법인  알수없음  7693  12105  3049021809
# 1  ID_5021  202201  여관업  제주도민    남성  3990   4291   294163241
#         ID      연월         업종명 이용자구분    성별    이용자수    이용건수
# 0  ID_2575  201911     한식 음식점업  제주도민    여성  153363  163462
# 1  ID_6637  202305  건강보조식품 소매업    법인  알수없음     136     144

# %%
print(train.shape, test.shape)
# Out:
# (2245, 8) (5020, 7)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2245 entries, 0 to 2244
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      2245 non-null   object
#  1   연월      2245 non-null   int64
#  2   업종명     2245 non-null   object
#  3   이용자구분   2245 non-null   object
#  4   성별      2245 non-null   object
#  5   이용자수    2245 non-null   int64
#  6   이용건수    2245 non-null   int64
#  7   이용금액    2245 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 140.4+ KB

# %%
test.info()   # target -> 이용금액
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5020 entries, 0 to 5019
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      5020 non-null   object
#  1   연월      5020 non-null   int64
#  2   업종명     5020 non-null   object
#  3   이용자구분   5020 non-null   object
#  4   성별      5020 non-null   object
#  5   이용자수    5020 non-null   int64
#  6   이용건수    5020 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 274.7+ KB

# %% [markdown]
# ### 문2) 종속변수 :이용금액 , 평가지표 : rmse -> ID별 이용금액을 구해서 그 결과를 csv 파일로 제출하고 rmse를 구하시오.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

# 1. 독립변수와 종속변수를 분리
y = train['이용금액']
x = train.drop(columns=['이용금액'])

# 2. Label Encoding
le = LabelEncoder()
le.fit(x['업종명'])

pre_x = x.copy()
pre_x = pre_x.drop(columns=['ID'])
pre_x['업종명'] = le.fit_transform(x['업종명'])
dum_x = pd.get_dummies(pre_x)

test_x = test.drop(columns=['ID'])
test_x['업종명'] = le.transform(test_x['업종명'])
dum_test = pd.get_dummies(test_x)
print(dum_x.shape, dum_test.shape)

# 3. train과 test를 분리
x_train, x_test, y_train, y_test = train_test_split(dum_x, y, random_state=123)

# 4. RandomForest Regressor 사용
rfr = RandomForestRegressor(random_state=123)
rfr.fit(x_train, y_train)
pred = rfr.predict(x_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print('test rmse: ', round(rmse, 4))

pred_test = rfr.predict(dum_test)

submission = pd.DataFrame()
submission['ID'] = test['ID']
submission['price'] = pred_test
submission.to_csv('test356.csv', index=False)
submission.head()
# Out:
# (2245, 14) (5020, 14)
# test rmse:  210016001.3973
#         ID         price
# 0  ID_2575  8.131837e+09
# 1  ID_6637  4.407935e+07
# 2  ID_5704  2.315762e+06
# 3  ID_3606  6.760848e+06
# 4  ID_6443  5.278640e+05

# %% [markdown]
# ## 7-3.작업 3유형

# %%
# 데이터url = https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p3_1.csv
# 종속변수 : Target

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p3_1.csv')
df.head()
# Out:
#       Target        v1        v2        v3        v4        v5        v6  \
# 0  21.650072  0.496714 -0.138264  0.647689  1.523030 -0.234153 -0.234137
# 1 -19.469855 -0.225776  0.067528 -1.424748 -0.544383  0.110923 -1.150994
# 2 -24.475600 -0.115648 -0.301104 -1.478522 -0.719844 -0.460639  1.057122
# 3  13.476831 -1.196207  0.812526  1.356240 -0.072010  1.003533  0.361636
# 4   3.505322 -0.808494 -0.501757  0.915402  0.328751 -0.529760  0.513267
#
#          v7        v8        v9  ...       v12       v13       v14       v15  \
# 0  1.579213  0.767435 -0.469474  ... -0.465730  0.241962 -1.913280 -1.724918
# 1  0.375698 -0.600639 -0.291694  ... -0.013497 -1.057711  0.822545 -1.220844
# 2  0.343618 -1.763040  0.324084  ...  0.611676  1.031000  0.931280 -0.839218
# 3 -0.645120  0.361396  1.538037  ... -2.619745  0.821903  0.087047 -0.299007
# 4  0.097078  0.968645 -0.702053  ... -1.463515  0.296120  0.261055  0.005113
#
#         v16       v17       v18       v19       v20       v21
# ...

# %%
print(df.shape)
df.info()
# Out:
# (1000, 22)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Target  1000 non-null   float64
#  1   v1      1000 non-null   float64
#  2   v2      1000 non-null   float64
#  3   v3      1000 non-null   float64
#  4   v4      1000 non-null   float64
#  5   v5      1000 non-null   float64
#  6   v6      1000 non-null   float64
#  7   v7      1000 non-null   float64
#  8   v8      1000 non-null   float64
#  9   v9      1000 non-null   float64
#  10  v10     1000 non-null   float64
#  11  v11     1000 non-null   float64
#  12  v12     1000 non-null   float64
#  13  v13     1000 non-null   float64
#  14  v14     1000 non-null   float64
#  15  v15     1000 non-null   float64
#  16  v16     1000 non-null   float64
#  17  v17     1000 non-null   float64
#  18  v18     1000 non-null   float64
#  19  v19     1000 non-null   float64
# ...

# %% [markdown]
# ### 문3-1) 종속변수 : Target에서 선형관계가 가장 큰 변수 찾아 상관계수를 구하여라

# %%
# result = df.corr()['Target'].sort_values()[-2]  # 이 방법으로는 경고문 발생
result = df.corr()['Target'].sort_values().iloc[-2]
result
# Out:
# 0.6270251925517436

# %% [markdown]
# ### 문3-2) Target 변수를 종속변수로 하여 다중선형회귀모델링을 진행했을 때 v2 컬럼의 회귀 계수는?

# %% [markdown]
# # 제 1유형 문제 풀이

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 문제1) 데이터 설명 : 유튜브 데일리 인기동영상 (한국)

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv",index_col=0)
print(df.shape)
df.head()
# Out:
# (60399, 9)
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60399 entries, 0 to 60398
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           60399 non-null  object
#  1   channelTitle    60399 non-null  object
#  2   categoryId      60399 non-null  int64
#  3   view_count      60399 non-null  int64
#  4   likes           60399 non-null  int64
#  5   dislikes        60399 non-null  int64
#  6   comment_count   60399 non-null  int64
#  7   channelId       60399 non-null  object
#  8   trending_date2  60399 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 6.6+ MB

# %% [markdown]
# ### 부분문제1) 인기동영상 제작횟수가 많은 채널 상위 10개명을 출력하라 (날짜기준, 중복포함)

# %%
# view_count ,  channelTitle  ,  channelId
top_10 = df.channelId.value_counts().head(10)
top_10
# Out:
# channelId
# UCszFjh7CEfwDb7UUGb4RzCQ    372
# UCtm_QoN2SIxwCE-59shX7Qg    318
# UClzB2iZ5jPoTNz0S-QU6Wiw    318
# UCaKod3X1Tn4c7Ci0iUKcvzQ    313
# UCiwQRG2sCcfjKkgxMEdJGPg    293
# UChbE5OZQ6dRHECsX0tEPEZQ    283
# UCLkAepWjdylmXSltofFvsYQ    275
# UCQ2O-iftmnlfrBuNsUUTofQ    274
# UCtfriFvIe5gIe8wRWb8UTMg    258
# UCRuSxVu4iqTK5kCh90ntAgA    255
# Name: count, dtype: int64

# %%
chn_id_10 = df.loc[df.channelId.isin(top_10.index)]

# %%
result = list(chn_id_10.channelTitle.unique())
result
# Out:
# ['장삐쭈',
#  '총몇명',
#  '파뿌리',
#  '짤툰',
#  '런닝맨 - 스브스 공식 채널',
#  '엠뚜루마뚜루 : MBC 공식 종합 채널',
#  'SPOTV',
#  '채널 십오야',
#  '이과장',
#  'BANGTANTV']

# %% [markdown]
# ### 부분문제2) 논란으로 인기동영상이 된 케이스를 확인하고 싶다. dislikes수가 like 수보다 높은 동영상을 제작한 채널을 모두 출력하라

# %%
# likes , dislikes ,  channelTitle
result = df.loc[df['likes'] < df['dislikes']].channelTitle.unique()
list(result)
# Out:
# ['핫도그TV',
#  'ASMR 애정TV',
#  '하얀트리HayanTree',
#  '양팡 YangPang',
#  '철구형 (CHULTUBE)',
#  '왜냐맨하우스',
#  '(MUTUBE)와꾸대장봉준',
#  '오메킴TV',
#  '육지담',
#  'MapleStory_KR',
#  'ROAD FIGHTING CHAMPIONSHIP',
#  '사나이 김기훈',
#  '나혼자산다 STUDIO',
#  'Gen.G esports']

# %% [markdown]
# ### 부분문제3) 채널명을 바꾼 케이스가 있는지 확인하고 싶다. channelId의 경우 고유값이므로 이를 통해 채널명을 한번이라도 바꾼 채널의 갯수를 구하여라

# %%
# channelTitle    channelId
change_df = df[['channelTitle', 'channelId']].drop_duplicates()
change_value = change_df.channelId.value_counts()
result = change_value[change_value > 1]
# result.count()
len(result)
# Out:
# 71

# %% [markdown]
# ### 부분문제4) 일요일에 인기있었던 영상들중 가장많은 영상 종류(categoryId)는 무엇인가?

# %%
# categoryId  trending_date2
df['trending_date2'] = pd.to_datetime(df['trending_date2'])
df['day_name'] = df['trending_date2'].dt.day_name()
# df.head()
res_df = df.loc[df['day_name'] == 'Sunday']
result = res_df.categoryId.value_counts().index[0]
result
# df['categoryId']
# Out:
# np.int64(24)

# %% [markdown]
# ### 부분문제5) 각 요일별 인기 영상들의 categoryId는 각각 몇개 씩인지 하나의 데이터 프레임으로 표현하라

# %%
df.head(1)
# Out:
#        title channelTitle  categoryId  view_count  likes  dislikes  \
# 0  [신병] 물자창고          장삐쭈          23     1893473  38249       730
#
#    comment_count                 channelId trending_date2 day_name
# 0           8595  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01   Friday

# %%
group = df.groupby([df['trending_date2'].dt.day_name(), 'categoryId'], as_index=False).size()
result = pd.crosstab(df['categoryId'], df['day_name'])
result
# Out:
# day_name    Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# categoryId
# 1              243     263       255     274       246      257        234
# 2              120     105       119      99       128      119        129
# 10             833     837       776     830       890      894        917
# 15             187     215       198     217       207      208        207
# 17             633     668       592     636       682      708        706
# 19              90      92        87      91        92       89         85
# 20             283     298       296     289       282      285        291
# 22            1288    1373      1289    1337      1341     1375       1333
# 23             568     594       570     556       560      569        566
# 24            2976    3148      3066    3096      2954     3084       3090
# 25             444     453       422     437       470      452        468
# ...

# %%
pd.crosstab(df['categoryId'], df['day_name'])
# Out:
# day_name    Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# categoryId
# 1              243     263       255     274       246      257        234
# 2              120     105       119      99       128      119        129
# 10             833     837       776     830       890      894        917
# 15             187     215       198     217       207      208        207
# 17             633     668       592     636       682      708        706
# 19              90      92        87      91        92       89         85
# 20             283     298       296     289       282      285        291
# 22            1288    1373      1289    1337      1341     1375       1333
# 23             568     594       570     556       560      569        566
# 24            2976    3148      3066    3096      2954     3084       3090
# 25             444     453       422     437       470      452        468
# ...

# %% [markdown]
# ### 부분문제6) 댓글의 수로 (comment_count) 영상 반응에 대한 판단을 할 수 있다. viewcount대비 댓글수가 가장 높은 영상을 확인하라 (view_count값이 0인 경우는 제외한다)

# %%
df.head(1)
# Out:
#        title channelTitle  categoryId  view_count  likes  dislikes  \
# 0  [신병] 물자창고          장삐쭈          23     1893473  38249       730
#
#    comment_count                 channelId trending_date2 day_name
# 0           8595  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01   Friday

# %%
# comment_count , view_count
df_1 = df.loc[df['view_count'] != 0]
new_df = df_1.copy()
new_df['ratio'] = (df_1['comment_count'] / df_1['view_count']).dropna()
res_df = new_df.sort_values(by='ratio', ascending=False)
result = res_df.sort_values(by='ratio', ascending=False).iloc[0].title
result
# Out:
# '60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)'

# %% [markdown]
# ### 부분문제7) 댓글의 수로 (comment_count) 영상 반응에 대한 판단을 할 수 있다.viewcount대비 댓글수가 가장 낮은 영상을 확인하라 (view_counts, ratio값이 0인경우는 제외한다.)

# %%
df.head(1)
# Out:
#        title channelTitle  categoryId  view_count  likes  dislikes  \
# 0  [신병] 물자창고          장삐쭈          23     1893473  38249       730
#
#    comment_count                 channelId trending_date2 day_name
# 0           8595  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01   Friday

# %%
# comment_count ,  view_count
ratio = (df['comment_count'] / df['view_count']).dropna().sort_values()
ratio[ratio != 0].index
# Out:
# Index([46005, 46210, 51798, 51579, 51353, 51136, 50910, 50027, 39792, 39573,
#        ...
#        52786, 51264, 51047, 50830,    44,   526,   740,  1180,   957,   297],
#       dtype='int64', length=59615)

# %%
result = df.iloc[ratio[ratio != 0].index[0]].title
result
# Out:
# 'Join the BTS #PermissiontoDance Challenge only on YouTube #Shorts'

# %% [markdown]
# ### 부분문제8) like 대비 dislike의 수가 가장 적은 영상은 무엇인가? (like, dislike 값이 0인경우는 제외한다)

# %%
df.head(1)
# Out:
#        title channelTitle  categoryId  view_count  likes  dislikes  \
# 0  [신병] 물자창고          장삐쭈          23     1893473  38249       730
#
#    comment_count                 channelId trending_date2 day_name
# 0           8595  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01   Friday

# %%
# likes , dislikes , title
target = df.loc[(df['likes'] !=0) & (df['dislikes'] != 0)]
res_df = (target['dislikes'] / target['likes']).sort_values()
num_df = res_df.index[0]
result = df.iloc[num_df].title
result
# Out:
# '[줌터뷰] *최초공개* 사부작즈🐰🐶의 비공식 이름은 아이라인즈? 꿀조합 티키타카 가득한 NCT 127 도영&정우의 줌터뷰'

# %% [markdown]
# ### 부분문제9) 가장많은 트렌드 영상을 제작한 채널의 이름은 무엇인가? (날짜기준, 중복포함)

# %%
df.head(1)
# Out:
#        title channelTitle  categoryId  view_count  likes  dislikes  \
# 0  [신병] 물자창고          장삐쭈          23     1893473  38249       730
#
#    comment_count                 channelId trending_date2 day_name
# 0           8595  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01   Friday

# %%
# channelTitle , trending_date2 , channelId
best_count = df['channelId'].value_counts().index[0]
result = df[df['channelId'] == best_count].channelTitle.unique()[0]
result
# Out:
# '짤툰'

# %% [markdown]
# ### 부분문제10) 20회(20일)이상 인기동영상 리스트에 포함된 동영상의 숫자는?

# %%
df.head(1)
# Out:
#        title channelTitle  categoryId  view_count  likes  dislikes  \
# 0  [신병] 물자창고          장삐쭈          23     1893473  38249       730
#
#    comment_count                 channelId trending_date2 day_name
# 0           8595  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01   Friday

# %%
# view_count , trending_date2
views = df[['title', 'channelId']].value_counts()
result = views[views >= 20].shape[0]
result
# Out:
# 40

# %% [markdown]
# ## 문제2) 데이터 설명 : 유튜브 “공범” 컨텐츠 동영상 정보 ( 10분 간격 수집)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
channel =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/channelInfo.csv')
video =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/videoInfo.csv')
display(channel.head(1))
display(video.head(1))
# Out:
#                   channelid   subcnt    viewcnt  videocnt  \
# 0  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  410238653       736
#
#                     ct channelname
# 0  2021-09-30 03:01:03         꽈뚜룹
#        videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 0  c5JQp6xafqc  1667010    30474         706            0   6587
#
#                     ct videoname
# 0  2021-10-10 15:20:03    공범 EP1

# %% [markdown]
# ### 부분문제11) 각 데이터의 ‘ct’컬럼을 시간으로 인식할수 있게 datetype을 변경하고 video 데이터의 videoname의 각 value 마다 몇개의 데이터씩 가지고 있는지 확인하라

# %%
# ct , videocnt
channel['ct'] = pd.to_datetime(channel['ct'])
video['ct']= pd.to_datetime(video['ct'])
video['videoname'].value_counts()
# Out:
# videoname
# 공범 EP1    3492
# 공범 EP2    3204
# 공범 EP3    2568
# 공범 EP4    2280
# 공범 EP5    1562
# 공범 EP6    1274
# 공범 EP7     555
# 공범 EP8     266
# Name: count, dtype: int64

# %% [markdown]
# ### 부분문제12) 수집된 각 video의 가장 최신화 된 날짜의 viewcount값을 출력하라

# %%
# videoname , ct
sorted = video.sort_values(['videoname', 'ct']).reset_index(drop=True).drop_duplicates(['videoname'], keep='last')
sorted[['viewcnt', 'videoname']]
# Out:
#        viewcnt videoname
# 3491   3180532    공범 EP1
# 6695   2199328    공범 EP2
# 9263   1671294    공범 EP3
# 11543  1818493    공범 EP4
# 13105  1503435    공범 EP5
# 14379  1750222    공범 EP6
# 14934  1630200    공범 EP7
# 15200  1289088    공범 EP8

# %% [markdown]
# ### 부분문제13) Channel 데이터중 2021-10-03일 이후 각 채널의 처음 기록 됐던 구독자 수(subcnt)를 출력하라

# %%
# ct , subcnt , channelname
channel_df = channel[channel['ct'] >= pd.to_datetime('2021-10-03')].sort_values(['channelname', 'ct'])
result = channel_df.drop_duplicates('channelname', keep='first')
result[['subcnt', 'channelname']]
# Out:
#        subcnt      channelname
# 1276    54300    Balming Tiger
# 1155   471000    곽토리 kwak tori
# 901      7520       김농밀의 농밀한 삶
# 12    1330000              꽈뚜룹
# 393    922000           논리왕 전기
# 1028    10100      릴펄 Lilpearl
# 139    257000            야전삽짱재
# 520     55000  와글와글 WagleWagle
# 647    215000              조나단
# 266    322000       츄정ChuJeong
# 774     14900          형사!탐정되다

# %% [markdown]
# ### 부분문제14) 각채널의 2021-10-03 03:00:00 ~ 2021-11-01 15:00:00 까지 구독자수 (subcnt) 의 증가량을 구하여라

# %%
# subcnt , ct , channelid
